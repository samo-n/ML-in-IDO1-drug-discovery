# %% [markdown]
# # Optimizacija hiperparametrov SVM

# %%
# %run __A_knjiznice.py

# Import specific elements from the script
from __A_knjiznice import *
from __B_funkcije import *
import __C_konstante as kon
# %matplotlib inline

# %%
import optuna
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.svm import SVC
from sklearn.feature_selection import SelectKBest, chi2, VarianceThreshold
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from optuna.pruners import MedianPruner

# Load your dataset
df = pd.read_csv(f'{kon.path_files}/molekulski_prstni_odtisi/df_rdkit.csv')
y = df[['Activity']].values.ravel()  # Assuming 'Activity' is the target
X = df.iloc[:, 3:]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=kon.random_seed, stratify=y)

# Define cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=kon.random_seed)

# Define the Optuna optimization function
def objective(trial):
    # Define hyperparameters for SVM with suggest_float (log-uniform sampling)
    C = trial.suggest_float('C', 1e-3, 10, log=True)  # Use suggest_float with log=True for log scale
    kernel = trial.suggest_categorical('kernel', ['linear', 'rbf', 'poly'])  # SVM kernel type
    gamma = trial.suggest_categorical('gamma', ['scale'])
    
    # Define feature selection (SelectKBest instead of SelectPercentile)
    k_best = trial.suggest_int('k_best', 5, 300)  # Limit the number of features selected
    
    # Create the pipeline
    model = Pipeline([
        ('variance_threshold', VarianceThreshold()),  # Remove low variance features
        ('select_k_best', SelectKBest(score_func=chi2, k=k_best)),  # Feature selection using SelectKBest
        ('svm', SVC(C=C, kernel=kernel, gamma=gamma, probability=True, random_state=kon.random_seed))  # SVM Classifier
    ])
    
    # Cross-validation: Optimize based on mean accuracy
    cv_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy')
    return np.mean(cv_scores)  # Return the mean of the cross-validation scores

# Create the Optuna study and optimize it
study = optuna.create_study(direction='maximize', pruner=MedianPruner())  # We want to maximize accuracy
study.optimize(objective, n_trials=50)  # Number of trials to run (can adjust this)

# Output the best trial results
print('Best trial:')
best_trial = study.best_trial
print(f"  Value: {best_trial.value}")
print(f"  Params: {best_trial.params}")
# Out:
# [I 2024-12-30 18:22:47,794] A new study created in memory with name: no-name-e6dd85e3-2352-4ee9-b002-7bd2f91badb0
# [I 2024-12-30 18:22:51,182] Trial 0 finished with value: 0.8530054271301829 and parameters: {'C': 5.094604039948622, 'kernel': 'poly', 'gamma': 'scale', 'k_best': 72}. Best is trial 0 with value: 0.8530054271301829.
# [I 2024-12-30 18:23:07,968] Trial 1 finished with value: 0.8364027832838922 and parameters: {'C': 1.8974201851532864, 'kernel': 'linear', 'gamma': 'scale', 'k_best': 298}. Best is trial 0 with value: 0.8530054271301829.
# [I 2024-12-30 18:23:10,946] Trial 2 finished with value: 0.827041781155874 and parameters: {'C': 8.031343063930635, 'kernel': 'poly', 'gamma': 'scale', 'k_best': 26}. Best is trial 0 with value: 0.8530054271301829.
# [I 2024-12-30 18:23:16,751] Trial 3 finished with value: 0.7890145042446447 and parameters: {'C': 0.010044551476043351, 'kernel': 'poly', 'gamma': 'scale', 'k_best': 204}. Best is trial 0 with value: 0.8530054271301829.
# [I 2024-12-30 18:23:25,685] Trial 4 finished with value: 0.7464650745262084 and parameters: {'C': 0.009106845182991648, 'kernel': 'rbf', 'gamma': 'scale', 'k_best': 208}. Best is trial 0 with value: 0.8530054271301829.
# [I 2024-12-30 18:24:34,063] Trial 5 finished with value: 0.835496894551453 and parameters: {'C': 7.867424793200114, 'kernel': 'linear', 'gamma': 'scale', 'k_best': 280}. Best is trial 0 with value: 0.8530054271301829.
# [I 2024-12-30 18:24:40,166] Trial 6 finished with value: 0.7283596031952171 and parameters: {'C': 0.004399637823896208, 'kernel': 'rbf', 'gamma': 'scale', 'k_best': 65}. Best is trial 0 with value: 0.8530054271301829.
# [I 2024-12-30 18:24:44,406] Trial 7 finished with value: 0.8511945610221778 and parameters: {'C': 4.188136833885246, 'kernel': 'poly', 'gamma': 'scale', 'k_best': 132}. Best is trial 0 with value: 0.8530054271301829.
# [I 2024-12-30 18:24:47,877] Trial 8 finished with value: 0.7893216315110754 and parameters: {'C': 0.0030008912239328353, 'kernel': 'linear', 'gamma': 'scale', 'k_best': 71}. Best is trial 0 with value: 0.8530054271301829.
# [I 2024-12-30 18:24:52,578] Trial 9 finished with value: 0.867795837833158 and parameters: {'C': 0.46292810859001726, 'kernel': 'poly', 'gamma': 'scale', 'k_best': 169}. Best is trial 9 with value: 0.867795837833158.
# [I 2024-12-30 18:24:56,985] Trial 10 finished with value: 0.8638692567429016 and parameters: {'C': 0.2900728966671717, 'kernel': 'poly', 'gamma': 'scale', 'k_best': 149}. Best is trial 9 with value: 0.867795837833158.
# [I 2024-12-30 18:25:01,160] Trial 11 finished with value: 0.8614555280629566 and parameters: {'C': 0.21887137998791914, 'kernel': 'poly', 'gamma': 'scale', 'k_best':
 'kernel': 'poly', 'gamma': 'scale', 'k_best': 298}. Best is trial 38 with value: 0.8726205611224271.
# [I 2024-12-30 18:27:26,579] Trial 39 finished with value: 0.8539081261135643 and parameters: {'C': 0.1778239404546438, 'kernel': 'rbf', 'gamma': 'scale', 'k_best': 297}. Best is trial 38 with value: 0.8726205611224271.
# [I 2024-12-30 18:27:32,455] Trial 40 finished with value: 0.8520940702565014 and parameters: {'C': 0.09043148809777368, 'kernel': 'poly', 'gamma': 'scale', 'k_best': 273}. Best is trial 38 with value: 0.8726205611224271.
# [I 2024-12-30 18:27:38,236] Trial 41 finished with value: 0.8720167871936132 and parameters: {'C': 0.3293395944087119, 'kernel': 'poly', 'gamma': 'scale', 'k_best': 296}. Best is trial 38 with value: 0.8726205611224271.
# [I 2024-12-30 18:27:43,843] Trial 42 finished with value: 0.8696016914783575 and parameters: {'C': 0.34825511831644884, 'kernel': 'poly', 'gamma': 'scale', 'k_best': 265}. Best is trial 38 with value: 0.8726205611224271.
# [I 2024-12-30 18:27:49,386] Trial 43 finished with value: 0.8656810342077803 and parameters: {'C': 1.50360598675901, 'kernel': 'poly', 'gamma': 'scale', 'k_best': 263}. Best is trial 38 with value: 0.8726205611224271.
# [I 2024-12-30 18:27:55,276] Trial 44 finished with value: 0.8720167871936132 and parameters: {'C': 0.29140651738114964, 'kernel': 'poly', 'gamma': 'scale', 'k_best': 298}. Best is trial 38 with value: 0.8726205611224271.
# [I 2024-12-30 18:28:00,578] Trial 45 finished with value: 0.8448551626088502 and parameters: {'C': 0.16182946257923517, 'kernel': 'linear', 'gamma': 'scale', 'k_best': 292}. Best is trial 38 with value: 0.8726205611224271.
# [I 2024-12-30 18:28:06,596] Trial 46 finished with value: 0.870810150692859 and parameters: {'C': 0.22468277099581113, 'kernel': 'poly', 'gamma': 'scale', 'k_best': 299}. Best is trial 38 with value: 0.8726205611224271.
# [I 2024-12-30 18:28:12,476] Trial 47 finished with value: 0.8699033506035461 and parameters: {'C': 1.007644868098414, 'kernel': 'poly', 'gamma': 'scale', 'k_best': 285}. Best is trial 38 with value: 0.8726205611224271.
# [I 2024-12-30 18:28:17,651] Trial 48 finished with value: 0.8650758932436557 and parameters: {'C': 5.696500395073913, 'kernel': 'poly', 'gamma': 'scale', 'k_best': 252}. Best is trial 38 with value: 0.8726205611224271.
# [I 2024-12-30 18:28:26,388] Trial 49 finished with value: 0.8022929738941824 and parameters: {'C': 0.03909510543662555, 'kernel': 'rbf', 'gamma': 'scale', 'k_best': 270}. Best is trial 38 with value: 0.8726205611224271.
# Best trial:
#   Value: 0.8726205611224271
#   Params: {'C': 0.33272587103394974, 'kernel': 'poly', 'gamma': 'scale', 'k_best': 298}

# %%
# Extract the best hyperparameters
best_params = best_trial.params
C = best_params['C']
kernel = best_params['kernel']
gamma = best_params['gamma']
k_best = best_params['k_best']

# Create the final pipeline with the best parameters
final_model = Pipeline([
    ('variance_threshold', VarianceThreshold()),  # Remove low variance features
    ('select_k_best', SelectKBest(score_func=chi2, k=k_best)),  # Feature selection using SelectKBest
    ('svm', SVC(C=C, kernel=kernel, gamma=gamma, probability=True, random_state=42))  # SVM with best parameters
])

# Fit the model on the full training data
final_model.fit(X_train, y_train)

# Predictions for train data
y_train_pred = final_model.predict(X_train)
y_train_prob = final_model.predict_proba(X_train)[:, 1]  # Probabilities for ROC AUC

# Predictions for test data
y_test_pred = final_model.predict(X_test)
y_test_prob = final_model.predict_proba(X_test)[:, 1]  # Probabilities for ROC AUC

# Calculate accuracy and AUC for train and test sets
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

train_auc = roc_auc_score(y_train, y_train_prob)
test_auc = roc_auc_score(y_test, y_test_prob)

# Plot ROC Curve
fpr_train, tpr_train, _ = roc_curve(y_train, y_train_prob)
fpr_test, tpr_test, _ = roc_curve(y_test, y_test_prob)

plt.figure(figsize=(10, 6))
plt.plot(fpr_train, tpr_train, color='blue', label=f'Train ROC Curve (AUC = {train_auc:.2f})')
plt.plot(fpr_test, tpr_test, color='red', label=f'Test ROC Curve (AUC = {test_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Random classifier line
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
# Confusion Matrix for Train and Test
train_cm = confusion_matrix(y_train, y_train_pred)
test_cm = confusion_matrix(y_test, y_test_pred)

# Print accuracy and AUC scores
print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Train AUC: {train_auc:.4f}")
print(f"Test AUC: {test_auc:.4f}")


# Display Confusion Matrix for Train data
fig, ax = plt.subplots(figsize=(6, 6))
ConfusionMatrixDisplay(confusion_matrix=train_cm).plot(cmap='Blues', ax=ax)
ax.set_title('Train Data Confusion Matrix')
plt.show()

# Display Confusion Matrix for Test data
fig, ax = plt.subplots(figsize=(6, 6))
ConfusionMatrixDisplay(confusion_matrix=test_cm).plot(cmap='Reds', ax=ax)
ax.set_title('Test Data Confusion Matrix')
plt.show()
# Out:
# Train Accuracy: 0.9152
# Test Accuracy: 0.8685
# Train AUC: 0.9747
# Test AUC: 0.9322
