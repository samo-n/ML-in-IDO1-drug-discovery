# %% [markdown]
# # Optimizacija hiperparametrov SVM

# %%
# %run __A_knjiznice.py

# Import specific elements from the script
from __A_knjiznice import *
from __B_funkcije import *
import __C_konstante as kon
# %matplotlib inline

# %%
import optuna
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.svm import SVC
from sklearn.feature_selection import SelectPercentile, chi2, VarianceThreshold
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay
import pandas as pd
import numpy as np
from optuna.pruners import MedianPruner

# Load your dataset
df = pd.read_csv(f'{kon.path_files}/molekulski_prstni_odtisi/df_circular.csv')
y = df[['Activity']].values.ravel()  # Assuming 'Activity' is the target
X = df.iloc[:, 3:]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=kon.random_seed, stratify=y)

# Define cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=kon.random_seed)

# Define the Optuna optimization function
def objective(trial):
    # SVM hyperparameters
    C = trial.suggest_float('C', 1e-3, 1.25, log=True)  # Log-uniform sampling
    kernel = trial.suggest_categorical('kernel', ['linear', 'rbf', 'poly'])  # SVM kernel type
    gamma = trial.suggest_categorical('gamma', ['scale'])
    
    # Feature selection with SelectPercentile
    percentile = trial.suggest_int('percentile', 5, 60)  # Percentile between 5 and 50
    
    # PCA for dimensionality reduction (always included)
    n_components = trial.suggest_float('pca_n_components', 0.1, 0.95)  # PCA float range
    
    # Build the pipeline
    model = Pipeline([
        ('variance_threshold', VarianceThreshold()),  # Remove low-variance features
        ('select_percentile', SelectPercentile(score_func=chi2, percentile=percentile)),  # Feature selection
        ('pca', PCA(n_components=n_components, random_state=kon.random_seed)),  # PCA always included
        ('svm', SVC(C=C, kernel=kernel, gamma=gamma, probability=True, random_state=kon.random_seed))  # SVM Classifier
    ])
    
    # Cross-validation: Optimize based on mean accuracy
    cv_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy')
    return np.mean(cv_scores)  # Return the mean of the cross-validation scores

# Create the Optuna study and optimize it
study = optuna.create_study(direction='maximize', pruner=MedianPruner())  # Maximize accuracy
study.optimize(objective, n_trials=100)  # Adjust n_trials as needed

# Output the best trial results
print('Best trial:')
best_trial = study.best_trial
print(f"  Value: {best_trial.value}")
print(f"  Params: {best_trial.params}")
# Out:
# [I 2025-01-26 19:55:51,892] A new study created in memory with name: no-name-75858ff9-abd0-4fae-b9e4-07d170189991
# [I 2025-01-26 19:55:53,456] Trial 0 finished with value: 0.6782450000683518 and parameters: {'C': 0.0387661181575975, 'kernel': 'poly', 'gamma': 'scale', 'percentile': 11, 'pca_n_components': 0.3682158329684717}. Best is trial 0 with value: 0.6782450000683518.
# [I 2025-01-26 19:55:55,859] Trial 1 finished with value: 0.8336864841218847 and parameters: {'C': 0.10580250828892745, 'kernel': 'linear', 'gamma': 'scale', 'percentile': 17, 'pca_n_components': 0.8687990994607603}. Best is trial 1 with value: 0.8336864841218847.
# [I 2025-01-26 19:55:59,588] Trial 2 finished with value: 0.8376116981768306 and parameters: {'C': 0.48707147371181575, 'kernel': 'poly', 'gamma': 'scale', 'percentile': 28, 'pca_n_components': 0.6073970427967921}. Best is trial 2 with value: 0.8376116981768306.
# [I 2025-01-26 19:56:01,112] Trial 3 finished with value: 0.604596428392412 and parameters: {'C': 0.0011852669447597476, 'kernel': 'poly', 'gamma': 'scale', 'percentile':
 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 60, 'pca_n_components': 0.8631558832643563}. Best is trial 77 with value: 0.8738326657644233.
# [I 2025-01-26 20:05:13,386] Trial 82 finished with value: 0.873530095282361 and parameters: {'C': 1.041095559186613, 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 60, 'pca_n_components': 0.8569465517478795}. Best is trial 77 with value: 0.8738326657644233.
# [I 2025-01-26 20:05:21,641] Trial 83 finished with value: 0.8732288918356094 and parameters: {'C': 1.0483617485293915, 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 60, 'pca_n_components': 0.8668223872599691}. Best is trial 77 with value: 0.8738326657644233.
# [I 2025-01-26 20:05:29,357] Trial 84 finished with value: 0.8747362761046784 and parameters: {'C': 1.0626490897117313, 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 60, 'pca_n_components': 0.8535207002096816}. Best is trial 84 with value: 0.8747362761046784.
# [I 2025-01-26 20:05:36,960] Trial 85 finished with value: 0.8735314623176716 and parameters: {'C': 1.2494956856461414, 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 59, 'pca_n_components': 0.8607013749345521}. Best is trial 84 with value: 0.8747362761046784.
# [I 2025-01-26 20:05:45,638] Trial 86 finished with value: 0.8548103694185087 and parameters: {'C': 1.2409008331016247, 'kernel': 'linear', 'gamma': 'scale', 'percentile': 60, 'pca_n_components': 0.8571225867291676}. Best is trial 84 with value: 0.8747362761046784.
# [I 2025-01-26 20:05:52,726] Trial 87 finished with value: 0.8680965856014728 and parameters: {'C': 0.6909576297213352, 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 60, 'pca_n_components': 0.8107808423845656}. Best is trial 84 with value: 0.8747362761046784.
# [I 2025-01-26 20:05:55,985] Trial 88 finished with value: 0.8261491070981031 and parameters: {'C': 0.030882045129257792, 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 15, 'pca_n_components': 0.7195952897755502}. Best is trial 84 with value: 0.8747362761046784.
# [I 2025-01-26 20:06:03,226] Trial 89 finished with value: 0.8738322100859864 and parameters: {'C': 1.0659222108574697, 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 55, 'pca_n_components': 0.8661634127081094}. Best is trial 84 with value: 0.8747362761046784.
# [I 2025-01-26 20:06:10,007] Trial 90 finished with value: 0.8674941787079694 and parameters: {'C': 0.6169569115418664, 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 55, 'pca_n_components': 0.7912564608814496}. Best is trial 84 with value: 0.8747362761046784.
# [I 2025-01-26 20:06:17,834] Trial 91 finished with value: 0.872926777031984 and parameters: {'C': 1.0107750551248356, 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 60, 'pca_n_components': 0.8635003228042604}. Best is trial 84 with value: 0.8747362761046784.
# [I 2025-01-26 20:06:25,574] Trial 92 finished with value: 0.8732284361571725 and parameters: {'C': 1.0892358678944287, 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 60, 'pca_n_components': 0.8615955800427411}. Best is trial 84 with value: 0.8747362761046784.
# [I 2025-01-26 20:06:29,671] Trial 93 finished with value: 0.8566280707030662 and parameters: {'C': 1.0807318771734276, 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 57, 'pca_n_components': 0.41791072722299166}. Best is trial 84 with value: 0.8747362761046784.
# [I 2025-01-26 20:06:38,008] Trial 94 finished with value: 0.8711149995671054 and parameters: {'C': 0.751078130913034, 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 55, 'pca_n_components': 0.9013418425257939}. Best is trial 84 with value: 0.8747362761046784.
# [I 2025-01-26 20:06:44,914] Trial 95 finished with value: 0.8732284361571725 and parameters: {'C': 1.248938583383959, 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 59, 'pca_n_components': 0.8102497690419059}. Best is trial 84 with value: 0.8747362761046784.
# [I 2025-01-26 20:06:56,356] Trial 96 finished with value: 0.6978560329546645 and parameters: {'C': 0.00638081431498728, 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 57, 'pca_n_components': 0.8535554514900363}. Best is trial 84 with value: 0.8747362761046784.
# [I 2025-01-26 20:07:00,245] Trial 97 finished with value: 0.8367112775856335 and parameters: {'C': 0.8043894173837431, 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 60, 'pca_n_components': 0.3500107860058397}. Best is trial 84 with value: 0.8747362761046784.
# [I 2025-01-26 20:07:07,307] Trial 98 finished with value: 0.8687012708871602 and parameters: {'C': 0.5970388315085305, 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 56, 'pca_n_components': 0.8246827182153198}. Best is trial 84 with value: 0.8747362761046784.
# [I 2025-01-26 20:07:11,088] Trial 99 finished with value: 0.711447098011875 and parameters: {'C': 1.0875405492078887, 'kernel': 'linear', 'gamma': 'scale', 'percentile': 59, 'pca_n_components': 0.10473572808423548}. Best is trial 84 with value: 0.8747362761046784.
# Best trial:
#   Value: 0.8747362761046784
#   Params: {'C': 1.0626490897117313, 'kernel': 'rbf', 'gamma': 'scale', 'percentile': 60, 'pca_n_components': 0.8535207002096816}

# %%
# Extract the best hyperparameters from Optuna
best_params = best_trial.params
C = best_params['C']
kernel = best_params['kernel']
gamma = best_params['gamma']
percentile = best_params['percentile']
pca_n_components = best_params['pca_n_components']

# Create the final pipeline with the best parameters
final_model = Pipeline([
    ('variance_threshold', VarianceThreshold()),  # Remove low variance features
    ('select_percentile', SelectPercentile(score_func=chi2, percentile=percentile)),  # Feature selection
    ('pca', PCA(n_components=pca_n_components, random_state=kon.random_seed)),  # Dimensionality reduction with PCA
    ('svm', SVC(C=C, kernel=kernel, gamma=gamma, probability=True, random_state=kon.random_seed))  # SVM with best parameters
])

# Fit the model on the full training data
final_model.fit(X_train, y_train)

# Predictions for train data
y_train_pred = final_model.predict(X_train)
y_train_prob = final_model.predict_proba(X_train)[:, 1]  # Probabilities for ROC AUC

# Predictions for test data
y_test_pred = final_model.predict(X_test)
y_test_prob = final_model.predict_proba(X_test)[:, 1]  # Probabilities for ROC AUC

# Calculate accuracy and AUC for train and test sets
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

train_auc = roc_auc_score(y_train, y_train_prob)
test_auc = roc_auc_score(y_test, y_test_prob)

# Print performance metrics
print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Train AUC: {train_auc:.4f}")
print(f"Test AUC: {test_auc:.4f}")

# Plot ROC Curve
fpr_train, tpr_train, _ = roc_curve(y_train, y_train_prob)
fpr_test, tpr_test, _ = roc_curve(y_test, y_test_prob)

plt.figure(figsize=(10, 6))
plt.plot(fpr_train, tpr_train, color='blue', label=f'Train ROC Curve (AUC = {train_auc:.2f})')
plt.plot(fpr_test, tpr_test, color='red', label=f'Test ROC Curve (AUC = {test_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Random classifier line
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# Train Accuracy: 0.9155
# Test Accuracy: 0.8770
# Train AUC: 0.9811
# Test AUC: 0.9453

# %%
# plot TEST only
plt.figure(figsize=(10, 6))
plt.plot(fpr_test, tpr_test, color='blue', label=f'ROC krivulja (AUC = {test_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Random classifier line
plt.title('ROC graf: SVM')
plt.xlabel('Delež lažno pozitivnih')
plt.ylabel('Delež resnično pozitivnih')
plt.legend(loc='lower right')
plt.show()

# %%
# Confusion Matrix for Train and Test
train_cm = confusion_matrix(y_train, y_train_pred)
test_cm = confusion_matrix(y_test, y_test_pred)

# Print accuracy and AUC scores
print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Train AUC: {train_auc:.4f}")
print(f"Test AUC: {test_auc:.4f}")


# Display Confusion Matrix for Train data
fig, ax = plt.subplots(figsize=(6, 6))
ConfusionMatrixDisplay(confusion_matrix=train_cm).plot(cmap='Blues', ax=ax)
ax.set_title('Train Data Confusion Matrix')
plt.show()

# Display Confusion Matrix for Test data
fig, ax = plt.subplots(figsize=(6, 6))
ConfusionMatrixDisplay(confusion_matrix=test_cm).plot(cmap='Reds', ax=ax)
ax.set_title('Test Data Confusion Matrix')
plt.show()
# Out:
# Train Accuracy: 0.9155
# Test Accuracy: 0.8770
# Train AUC: 0.9811
# Test AUC: 0.9453
