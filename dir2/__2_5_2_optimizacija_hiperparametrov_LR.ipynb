# %% [markdown]
# # Optimizacija hiperparametrov LR

# %%
# %run __A_knjiznice.py

# Import specific elements from the script
from __A_knjiznice import *
from __B_funkcije import *
import __C_konstante as kon
# %matplotlib inline

# %%
import optuna
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectKBest, chi2, VarianceThreshold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv(f'{kon.path_files}/molekulski_prstni_odtisi/df_circular.csv')
y = df[['Activity']].values.ravel()  # Assuming 'Activity' is the target
X = df.iloc[:, 3:]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=kon.random_seed, stratify=y)

# Define cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=kon.random_seed)  # Increased folds for more robustness

# Define the Optuna optimization function
def objective(trial):
    # Define hyperparameters for LogisticRegression
    C = trial.suggest_float('C', 1e-5, 1e5, log=True)  # Inverse of regularization strength on a log scale
    solver = trial.suggest_categorical('solver', ['liblinear', 'lbfgs', 'saga'])  # Tuning solver
    max_iter = trial.suggest_int('max_iter', 100, 2000)  # Maximum number of iterations for convergence
    
    # Define feature selection (SelectKBest)
    k_best = trial.suggest_int('k_best', 5, 300)  # Limit number of features to select
    
    # Create the pipeline without PCA
    steps = [
        ('variance_threshold', VarianceThreshold()),  # Apply VarianceThreshold to remove low-variance features
        ('select_k_best', SelectKBest(score_func=chi2, k=k_best)),  # Feature selection using SelectKBest
        ('lr', LogisticRegression(C=C, solver=solver, max_iter=max_iter, random_state=kon.random_seed))  # Logistic Regression
    ]
    
    # Create the pipeline with the selected steps
    model = Pipeline(steps)
    
    # Cross-validation: Optimize based on mean accuracy
    cv_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy')
    return np.mean(cv_scores)  # Return the mean of the cross-validation scores

# Create the Optuna study and optimize it
study = optuna.create_study(direction='maximize')  # We want to maximize accuracy
study.optimize(objective, n_trials=50)  # Number of trials to run (can adjust this)

# Output the best trial results
print('Best trial:')
best_trial = study.best_trial
print(f"  Value: {best_trial.value}")
print(f"  Params: {best_trial.params}")
# Out:
# [I 2024-12-30 19:43:12,305] A new study created in memory with name: no-name-a768f53c-d789-4014-87d8-c4887babd99b
# [I 2024-12-30 19:43:12,931] Trial 0 finished with value: 0.8098408315220116 and parameters: {'C': 70.22207975686683, 'solver': 'saga', 'max_iter': 1818, 'k_best': 86}. Best is trial 0 with value: 0.8098408315220116.
# [I 2024-12-30 19:43:13,091] Trial 1 finished with value: 0.7932404660679052 and parameters: {'C': 62838.766768545574, 'solver': 'liblinear', 'max_iter': 1300, 'k_best': 70}. Best is trial 0 with value: 0.8098408315220116.
# [I 2024-12-30 19:43:13,281] Trial 2 finished with value: 0.8273525538497994 and parameters: {'C': 84261.71647373535, 'solver': 'liblinear', 'max_iter': 489, 'k_best': 202}. Best is trial 2 with value: 0.8273525538497994.
# [I 2024-12-30 19:43:13,587] Trial 3 finished with value: 0.823729454598479 and parameters: {'C': 866.6050971433493, 'solver': 'lbfgs', 'max_iter': 1373, 'k_best': 124}. Best is trial 2 with value: 0.8273525538497994.
# [I 2024-12-30 19:43:13,739] Trial 4 finished with value: 0.7268421940005376 and parameters: {'C': 0.0012133881413272938, 'solver': 'liblinear', 'max_iter': 970, 'k_best': 58}. Best is trial 2 with value: 0.8273525538497994.
# [I 2024-12-30 19:43:13,883] Trial 5 finished with value: 0.7364989314340656 and parameters: {'C': 0.001069603661048213, 'solver': 'liblinear', 'max_iter': 982, 'k_best': 69}. Best is trial 2 with value: 0.8273525538497994.
# [I 2024-12-30 19:43:14,025] Trial 6 finished with value: 0.8101516042159368 and parameters: {'C': 0.00333651464999871, 'solver': 'liblinear', 'max_iter': 1293, 'k_best': 163}. Best is trial 2 with value: 0.8273525538497994.
# [I 2024-12-30 19:43
. Best is trial 13 with value: 0.8536114794511809.
# [I 2024-12-30 19:43:19,143] Trial 25 finished with value: 0.8324844044054991 and parameters: {'C': 0.9266657046880858, 'solver': 'saga', 'max_iter': 1102, 'k_best': 185}. Best is trial 13 with value: 0.8536114794511809.
# [I 2024-12-30 19:43:19,388] Trial 26 finished with value: 0.8524007418444952 and parameters: {'C': 0.05290223751195028, 'solver': 'lbfgs', 'max_iter': 300, 'k_best': 261}. Best is trial 13 with value: 0.8536114794511809.
# [I 2024-12-30 19:43:19,578] Trial 27 finished with value: 0.8182986789882116 and parameters: {'C': 0.0033675676911192483, 'solver': 'lbfgs', 'max_iter': 740, 'k_best': 245}. Best is trial 13 with value: 0.8536114794511809.
# [I 2024-12-30 19:43:19,910] Trial 28 finished with value: 0.8403320984447695 and parameters: {'C': 25.150341328735813, 'solver': 'lbfgs', 'max_iter': 441, 'k_best': 299}. Best is trial 13 with value: 0.8536114794511809.
# [I 2024-12-30 19:43:20,997] Trial 29 finished with value: 0.8484773505032969 and parameters: {'C': 0.7093506948201358, 'solver': 'saga', 'max_iter': 1158, 'k_best': 226}. Best is trial 13 with value: 0.8536114794511809.
# [I 2024-12-30 19:43:21,224] Trial 30 finished with value: 0.8521004497546171 and parameters: {'C': 0.09419345332500417, 'solver': 'lbfgs', 'max_iter': 1654, 'k_best': 270}. Best is trial 13 with value: 0.8536114794511809.
# [I 2024-12-30 19:43:21,562] Trial 31 finished with value: 0.8487817436991065 and parameters: {'C': 1.7873533472424492, 'solver': 'lbfgs', 'max_iter': 260, 'k_best': 282}. Best is trial 13 with value: 0.8536114794511809.
# [I 2024-12-30 19:43:21,956] Trial 32 finished with value: 0.8542134306662474 and parameters: {'C': 0.46454735620212956, 'solver': 'lbfgs', 'max_iter': 195, 'k_best': 298}. Best is trial 32 with value: 0.8542134306662474.
# [I 2024-12-30 19:43:22,173] Trial 33 finished with value: 0.8339931557098786 and parameters: {'C': 0.008241109103758896, 'solver': 'lbfgs', 'max_iter': 470, 'k_best': 258}. Best is trial 32 with value: 0.8542134306662474.
# [I 2024-12-30 19:43:22,364] Trial 34 finished with value: 0.8360993014449563 and parameters: {'C': 0.12551233578752835, 'solver': 'lbfgs', 'max_iter': 250, 'k_best': 181}. Best is trial 32 with value: 0.8542134306662474.
# [I 2024-12-30 19:43:22,551] Trial 35 finished with value: 0.7853904936364506 and parameters: {'C': 0.00043902034515218936, 'solver': 'lbfgs', 'max_iter': 614, 'k_best': 299}. Best is trial 32 with value: 0.8542134306662474.
# ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
# [I 2024-12-30 19:43:26,120] Trial 36 finished with value: 0.8397292358728293 and parameters: {'C': 22.548369011398595, 'solver': 'saga', 'max_iter': 413, 'k_best': 277}. Best is trial 32 with value: 0.8542134306662474.
# [I 2024-12-30 19:43:26,352] Trial 37 finished with value: 0.83761033114152 and parameters: {'C': 254.7187956144512, 'solver': 'liblinear', 'max_iter': 821, 'k_best': 229}. Best is trial 32 with value: 0.8542134306662474.
# [I 2024-12-30 19:43:26,553] Trial 38 finished with value: 0.8225196283486669 and parameters: {'C': 0.6635666082587283, 'solver': 'lbfgs', 'max_iter': 895, 'k_best': 128}. Best is trial 32 with value: 0.8542134306662474.
# [I 2024-12-30 19:43:26,783] Trial 39 finished with value: 0.8361052252646353 and parameters: {'C': 6446.825389448344, 'solver': 'liblinear', 'max_iter': 201, 'k_best': 255}. Best is trial 32 with value: 0.8542134306662474.
# [I 2024-12-30 19:43:26,949] Trial 40 finished with value: 0.7265409905537861 and parameters: {'C': 0.005777768371821663, 'solver': 'lbfgs', 'max_iter': 1237, 'k_best': 23}. Best is trial 32 with value: 0.8542134306662474.
# [I 2024-12-30 19:43:27,184] Trial 41 finished with value: 0.8505921541286746 and parameters: {'C': 0.27496618620528945, 'solver': 'lbfgs', 'max_iter': 128, 'k_best': 287}. Best is trial 32 with value: 0.8542134306662474.
# [I 2024-12-30 19:43:27,415] Trial 42 finished with value: 0.8533098203259923 and parameters: {'C': 0.3628262175346353, 'solver': 'lbfgs', 'max_iter': 355, 'k_best': 287}. Best is trial 32 with value: 0.8542134306662474.
# [I 2024-12-30 19:43:27,665] Trial 43 finished with value: 0.847575562876789 and parameters: {'C': 1.4817504244837276, 'solver': 'lbfgs', 'max_iter': 359, 'k_best': 273}. Best is trial 32 with value: 0.8542134306662474.
# [I 2024-12-30 19:43:27,925] Trial 44 finished with value: 0.8448588080363448 and parameters: {'C': 5.704787399674711, 'solver': 'lbfgs', 'max_iter': 514, 'k_best': 285}. Best is trial 32 with value: 0.8542134306662474.
# [I 2024-12-30 19:43:28,137] Trial 45 finished with value: 0.8499874688429869 and parameters: {'C': 0.055025525513345254, 'solver': 'liblinear', 'max_iter': 227, 'k_best': 299}. Best is trial 32 with value: 0.8542134306662474.
# [I 2024-12-30 19:43:28,366] Trial 46 finished with value: 0.8143707308626448 and parameters: {'C': 0.345880810343585, 'solver': 'lbfgs', 'max_iter': 377, 'k_best': 88}. Best is trial 32 with value: 0.8542134306662474.
# [I 2024-12-30 19:43:28,571] Trial 47 finished with value: 0.7977708210869754 and parameters: {'C': 0.000941610432832655, 'solver': 'lbfgs', 'max_iter': 971, 'k_best': 252}. Best is trial 32 with value: 0.8542134306662474.
# [I 2024-12-30 19:43:28,771] Trial 48 finished with value: 0.8222184249019152 and parameters: {'C': 0.016121501485273294, 'solver': 'lbfgs', 'max_iter': 557, 'k_best': 142}. Best is trial 32 with value: 0.8542134306662474.
# [I 2024-12-30 19:43:29,411] Trial 49 finished with value: 0.8463639139132297 and parameters: {'C': 0.0978533295247979, 'solver': 'saga', 'max_iter': 295, 'k_best': 233}. Best is trial 32 with value: 0.8542134306662474.
# Best trial:
#   Value: 0.8542134306662474
#   Params: {'C': 0.46454735620212956, 'solver': 'lbfgs', 'max_iter': 195, 'k_best': 298}

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# Extract the best hyperparameters
best_params = best_trial.params
C = best_params['C']
solver = best_params['solver']
max_iter = best_params['max_iter']
k_best = best_params['k_best']

# Create the final pipeline with the best parameters
final_model = Pipeline([
    ('variance_threshold', VarianceThreshold()),  # Apply VarianceThreshold
    ('select_k_best', SelectKBest(score_func=chi2, k=k_best)),  # Feature selection using SelectKBest
    ('lr', LogisticRegression(C=C, solver=solver, max_iter=max_iter, random_state=kon.random_seed))  # Logistic Regression with the best parameters
])

# Fit the model on the full training data
final_model.fit(X_train, y_train)

# Predictions for train data
y_train_pred = final_model.predict(X_train)
y_train_prob = final_model.predict_proba(X_train)[:, 1]  # Probabilities for ROC AUC

# Predictions for test data
y_test_pred = final_model.predict(X_test)
y_test_prob = final_model.predict_proba(X_test)[:, 1]  # Probabilities for ROC AUC

# Calculate accuracy and AUC for train and test sets
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

train_auc = roc_auc_score(y_train, y_train_prob)
test_auc = roc_auc_score(y_test, y_test_prob)

# Plot ROC Curve
fpr_train, tpr_train, _ = roc_curve(y_train, y_train_prob)
fpr_test, tpr_test, _ = roc_curve(y_test, y_test_prob)

plt.figure(figsize=(10, 6))
plt.plot(fpr_train, tpr_train, color='blue', label=f'Train ROC Curve (AUC = {train_auc:.2f})')
plt.plot(fpr_test, tpr_test, color='red', label=f'Test ROC Curve (AUC = {test_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Random classifier line
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
# Confusion Matrix for Train and Test
train_cm = confusion_matrix(y_train, y_train_pred)
test_cm = confusion_matrix(y_test, y_test_pred)

# Print accuracy and AUC scores
print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Train AUC: {train_auc:.4f}")
print(f"Test AUC: {test_auc:.4f}")


# Display Confusion Matrix for Train data
fig, ax = plt.subplots(figsize=(6, 6))
ConfusionMatrixDisplay(confusion_matrix=train_cm).plot(cmap='Blues', ax=ax)
ax.set_title('Train Data Confusion Matrix')
plt.show()

# Display Confusion Matrix for Test data
fig, ax = plt.subplots(figsize=(6, 6))
ConfusionMatrixDisplay(confusion_matrix=test_cm).plot(cmap='Reds', ax=ax)
ax.set_title('Test Data Confusion Matrix')
plt.show()
# Out:
# Train Accuracy: 0.8874
# Test Accuracy: 0.8504
# Train AUC: 0.9541
# Test AUC: 0.9251
