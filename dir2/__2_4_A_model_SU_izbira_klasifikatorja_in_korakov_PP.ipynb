# %% [markdown]
# # 2.3A Izbira modela za strojno učenje

# %% [markdown]
# V koraku izbira modela za strojno učenje:
# - uvozimo podatke pridobljene v koraku 2. s katerih bomo učili modele
# - podatke o strukturah molekule pretvorimo v fingerprinte (bitni zapis strukture, s tem dobimo featurje na X osi)
# - izberemo kombinacijo najbolj primernega fingerprinta, klasifikatorja, vzorčenjske tehnike, skalarja, tehnike za zaznavanje outlierjev

# %% [markdown]
# # Uvoz knjižnic in splošnih funkcij

# %%
# %run __A_knjiznice.py

from __A_knjiznice import *
from __B_funkcije import *
import __C_konstante as kon
# %matplotlib inline

# %% [markdown]
# # Uvoz obdelanih podatkov obdelanih v koraku 2. Obdelava in analiza podatkov

# %% [markdown]
# ## Pregled podatkov

# %%
df = pd.read_csv(f'{kon.path_files}/dp.csv')
df
# Out:
#                                                  Smiles  \
# 0          O=C1c2cc([N+](=O)[O-])ccc2-n2c1nc1ccccc1c2=O
# 1     Cc1cc(C2CC2)ncc1-c1ccc(C2(C(=O)Nc3ccc(F)cc3)CO...
# 2     O=C(Nc1ccc(C2(C(=O)Nc3ccc(F)cc3)COC2)cc1)c1ccc...
# 3     O=C(Nc1ccc(F)cc1)C1(C2CCC3C(CCCN3c3ccnc(C(F)(F...
# 4                    O=C1CC(c2c[nH]c3ccc(F)cc23)C(=O)N1
# ...                                                 ...
# 4137                      FC(F)(F)c1ccc(-c2c[nH]nn2)cc1
# 4138                                   c1ccc2[nH]nnc2c1
# 4139               Cc1cccc(NC(=O)C(F)(F)F)c1-c1c[nH]nn1
# 4140                            Cc1ccc(N)cc1-c1c[nH]nn1
# 4141                            COc1ccc(-c2cnn[nH]2)cc1
#
#                                               ROMol  Activity
# 0     <rdkit.Chem.rdchem.Mol object at 0x16fce49e0>         1
# 1     <rdkit.Chem.rdchem.Mol object at 0x16fcb09e0>         1
# 2     <rdkit.Chem.rdchem.Mol object at 0x16fcdcba0>         1
# 3     <rdkit.Chem.rdchem.Mol object at 0x16fcddcb0>         1
# 4     <rdkit.Chem.rdchem.Mol object at 0x16fce25e0>         1
# ...                                             ...       ...
# 4137  <rdkit.Chem.rdchem.Mol object at 0x16fcbef10>         0
# 4138  <rdkit.Chem.rdchem.Mol object at 0x16fcf54d0>         0
# 4139  <rdkit.Chem.rdchem.Mol object at 0x16fcb5230>         0
# 4140  <rdkit.Chem.rdchem.Mol object at 0x16fcb2500>         0
# 4141  <rdkit.Chem.rdchem.Mol object at 0x16fca2570>         0
#
# [4142 rows x 3 columns]

# %%
activity_counts = df['Activity'].value_counts()
print(activity_counts)
# Out:
# Activity
# 1    2103
# 0    2039
# Name: count, dtype: int64

# %% [markdown]
# # 3.3 Izračun relevantnih metrik za model strojnega učenja

# %% [markdown]
# ## Test different fingerprints

# %% [markdown]
# **standard**: Considers paths of a given length. These are hashed fingerprints, with a default length of 1024.
# **extended**: Similar to the standard type, but takes rings and atomic properties into account into account.
# **graph**: Similar to the standard type by simply considers connectivity.
# **hybridization**: Similar to the standard type, but only consider hybridization state.
# **estate**: 79 bit fingerprints corresponding to the E-State atom types described by Hall and Kier.
# **cdk-atompairs**: CDK's implementation of the atompairs fingerprint
# **cdk-substructure**: CDK substructure fingerprint, basically identical to openbabel's fp4.
# **pubchem**: 881 bit fingerprints defined by PubChem.
# **klekota-roth**: 4860 bit fingerprint defined by Klekota and Roth.
# **shortestpath**: A fingerprint based on the shortest paths between pairs of atoms and takes into account ring systems, charges etc.
# **rdk-descriptor**: Various molecular descriptors implemented and calculated by RDKit.
# **circular**: An implementation of the ECFP6 fingerprint.
# **lingo**: An implementation of the LINGO fingerprint.
# **rdkit**: Another implementation of a Daylight-like fingerprint by RDKit.
# **maccs**: The popular 166 bit MACCS keys described by MDL.
# **avalon**: Substructure or similarity Avalon fingerprint.
# **atom-pair**: RDKit Atom-Pair fingerprint.
# **topological-torsion**: RDKit Topological-Torsion Fingerprint.
# **morgan**: RDKit Morgan fingerprint.
# **fp2**: OpenBabel FP2 fingerprint, which indexes small molecule fragments based on linear segments of up to 7 atoms in length.
# **fp3**: OpenBabel FP3 fingerprint, which is a fingerprint method created from a set of SMARTS patterns defining functional groups.
# **fp4**: OpenBabel FP4 fingerprint, which is a fingerprint method created from a set of SMARTS patterns defining functional groups.
# **spectrophore** Openbabel implementation of the spectrophore fingerprint (https://github.com/silicos-it/spectrophore).
# **mol2vec**: Unsupervised machine learning approach for mulecule representation.

# %% [markdown]
# # Pregled kombinacij izbranih fingerprintov in klasifikacijskih modelov

# %% [markdown]
# ## V tem koraku bi rad preveril katera kombinacija fingerprinta in klasifikacijskega modela je najboljša preden začnem manipulirati s podatki. Ta korak je pomemben zato da v nadaljnih korakih vidim kaj izboljšujem

# %%
# https://medium.com/artificialis/why-how-we-split-train-valid-and-test-fb4d6746ede

# %%
input_directory = f'{kon.path_files}/molekulski_prstni_odtisi'

generated_fingerprints = ['df_standard.csv', 'df_extended.csv', 'df_graph.csv', 'df_maccs.csv', 'df_pubchem.csv', 
 'df_estate.csv', 'df_hybridization.csv', 'df_lingo.csv', 'df_klekota-roth.csv', 'df_shortestpath.csv', 
 'df_cdk-substructure.csv', 'df_circular.csv', 'df_cdk-atompairs.csv', 'df_rdkit.csv', 'df_morgan.csv', 
 'df_rdk-maccs.csv', 'df_topological-torsion.csv', 'df_avalon.csv', 'df_atom-pair.csv', 'df_fp2.csv']

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_validate
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
from imblearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import VarianceThreshold, SelectPercentile, chi2, SelectKBest
from sklearn.decomposition import PCA
from xgboost import XGBClassifier  # Make sure to import XGBClassifier
import numpy as np

# Define classifiers with random_state for reproducibility
classifiers = [
    ('svm', SVC(probability=True, random_state=kon.random_seed)),
    ('lr', LogisticRegression(random_state=kon.random_seed, max_iter=1000)),
    ('rf', RandomForestClassifier(
        n_jobs=-1,
        random_state=kon.random_seed,
        max_features='sqrt',
        min_samples_split=5,
        min_samples_leaf=5,
        max_depth=20,
        bootstrap=True,
        n_estimators=100
    )),
    ('xgb', XGBClassifier(
        objective='binary:logistic',
        eval_metric='logloss',
        random_state=kon.random_seed,
        n_jobs=-1,
        max_depth=6,
        min_child_weight=5,
        learning_rate=0.05,
        n_estimators=100,
        gamma=0.3
    ))
]

# Feature selection preprocessing steps
feature_selection_steps = [
    ('select_percentile_25', SelectPercentile(score_func=chi2, percentile=25)),
    ('select_percentile_50', SelectPercentile(score_func=chi2, percentile=50))
]

# Dimensionality reduction options
dimensionality_reduction = [
    ('pca', PCA(n_components=0.9, random_state=kon.random_seed)),
    ('none', 'passthrough')
]

# Stratified k-fold cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=kon.random_seed)
scoring = {'accuracy': 'accuracy', 'f1': 'f1', 'precision': 'precision', 'recall': 'recall', 'roc_auc': 'roc_auc'}
results_list = []


for filename in generated_fingerprints:
    file_path = os.path.join(input_directory, filename)
    
    if os.path.exists(file_path):
        print(f'Processing fingerprint DataFrame: {filename}')
        
        # Load the fingerprint data
        df = pd.read_csv(file_path)
        fingerprint_name = filename.split('df_')[1].split('.')[0]
        y = df['Activity'].values.ravel()
        X = df.iloc[:, 3:]
        
        # Split the data into train and test
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=kon.random_seed, stratify=y)
        
        # Loop over classifiers, feature selection methods, and dimensionality reduction
        for clf_name, classifier in classifiers:
            for prep_name, prep_step in feature_selection_steps:
                for dr_name, dr_step in dimensionality_reduction:
                    print(f"Training {clf_name} with {prep_name} and {dr_name} on {fingerprint_name}...")
                    
                    # Define the pipeline steps
                    steps = [
                        ('variance_threshold', VarianceThreshold()),
                        (prep_name, prep_step),
                        (dr_name, dr_step),
                        ('classifier', classifier)
                    ]
                    
                    # Create the pipeline
                    pipeline = Pipeline(steps)
                    
                    # Cross-validation to evaluate the model
                    cv_results = cross_validate(pipeline, X_train, y_train, cv=cv, scoring=scoring, return_train_score=True)
                    
                    # Fit the pipeline and predict on the test set
                    pipeline.fit(X_train, y_train)
                    y_test_pred = pipeline.predict(X_test)
                    
                    # Calculate metrics on the test set
                    test_accuracy = accuracy_score(y_test, y_test_pred)
                    test_f1 = f1_score(y_test, y_test_pred)
                    test_precision = precision_score(y_test, y_test_pred)
                    test_recall = recall_score(y_test, y_test_pred)
                    test_roc_auc = roc_auc_score(y_test, y_test_pred)
                    
                    # Store the results including the feature selection and dimensionality reduction methods used
                    results_temp = {
                        'Fingerprint': fingerprint_name,
                        'Classifier': clf_name,
                        'Feature_Selection_Method': prep_name,  # Store feature selection method
                        'Dimensionality_Reduction_Method': dr_name,  # Store dimensionality reduction method
                        # 'Steps': str(steps),  # Store the steps as string representation
                        'CV_Train_Accuracy_Folds': list(cv_results['train_accuracy']),
                        'CV_Train_Mean_Accuracy': cv_results['train_accuracy'].mean(),
                        'CV_Train_Mean_F1': cv_results['train_f1'].mean(),
                        'CV_Train_Mean_Precision': cv_results['train_precision'].mean(),
                        'CV_Train_Mean_Recall': cv_results['train_recall'].mean(),
                        'CV_Train_Mean_ROC_AUC': cv_results['train_roc_auc'].mean(),
                        'CV_Val_Accuracy_Folds': list(cv_results['test_accuracy']),
                        'CV_Val_Mean_Accuracy': cv_results['test_accuracy'].mean(),
                        'CV_Val_Mean_F1': cv_results['test_f1'].mean(),
                        'CV_Val_Mean_Precision': cv_results['test_precision'].mean(),
                        'CV_Val_Mean_Recall': cv_results['test_recall'].mean(),
                        'CV_Val_Mean_ROC_AUC': cv_results['test_roc_auc'].mean(),
                        'Test_Accuracy': test_accuracy,
                        'Test_F1': test_f1,
                        'Test_Precision': test_precision,
                        'Test_Recall': test_recall,
                        'Test_ROC_AUC': test_roc_auc
                    }
                    
                    # Append the results for this configuration
                    results_list.append(results_temp)
                    print(results_temp)

# Convert the results list into a DataFrame
results_df = pd.DataFrame(results_list)
# Out:
# Processing fingerprint DataFrame: df_standard.csv
# Training svm with select_percentile_25 and pca on standard...
# {'Fingerprint': 'standard', 'Classifier': 'svm', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.8950943396226415, 0.8883018867924528, 0.889433962264151, 0.8890984534138061, 0.8902301018483592], 'CV_Train_Mean_Accuracy': 0.8904317487882821, 'CV_Train_Mean_F1': 0.8942105740798171, 'CV_Train_Mean_Precision': 0.8769680437647421, 'CV_Train_Mean_Recall': 0.9121587299833734, 'CV_Train_Mean_ROC_AUC': 0.9623834065923791, 'CV_Val_Accuracy_Folds': [0.8642533936651584, 0.8702865761689291, 0.8567119155354449, 0.851963746223565, 0.8625377643504532], 'CV_Val_Mean_Accuracy': 0.86115067918871, 'CV_Val_Mean_F1': 0.866663276436382, 'CV_Val_Mean_Precision': 0.8458380297438955, 'CV_Val_Mean_Recall': 0.8888300127172531, 'CV_Val_Mean_ROC_AUC': 0.9291842774501748, 'Test_Accuracy': 0.8757539203860072, 'Test_F1': 0.8760529482551144, 'Test_Precision': 0.8878048780487805, 'Test_Recall': 0.8646080760095012, 'Test_ROC_AUC': 0.8759314889851426}
# Training svm with select_percentile_25 and none on standard...
# {'Fingerprint': 'standard', 'Classifier': 'svm', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.9018867924528302, 0.8969811320754717, 0.8981132075471698, 0.8985288570350811, 0.8992832893247831], 'CV_Train_Mean_Accuracy': 0.8989586556870671, 'CV_Train_Mean_F1': 0.9026197977763738, 'CV_Train_Mean_Precision': 0.8836963704344155, 'CV_Train_Mean_Recall': 0.9224145340455265, 'CV_Train_Mean_ROC_AUC': 0.9685619393777518, 'CV_Val_Accuracy_Folds': [0.8717948717948718, 0.8672699849170438, 0.8597285067873304, 0.850453172205438, 0.8580060422960725], 'CV_Val_Mean_Accuracy': 0.8614505156001513, 'CV_Val_Mean_F1': 0.8667815477457157, 'CV_Val_Mean_Precision': 0.8470343691542149, 'CV_Val_Mean_Recall': 0.8876342376713297, 'CV_Val_Mean_ROC_AUC': 0.9297499431184008, 'Test_Accuracy': 0.8721351025331725, 'Test_F1': 0.8735083532219571, 'Test_Precision': 0.8776978417266187, 'Test_Recall': 0.8693586698337292, 'Test_ROC_AUC': 0.8721793349168646}
# Training svm with select_percentile_50 and pca on standard...
# {'Fingerprint': 'standard', 'Classifier': 'svm', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.8958490566037736, 0.8905660377358491, 0.8935849056603774, 0.8932478310071671, 0.8909845341380611], 'CV_Train_Mean_Accuracy': 0.8928464730290457, 'CV_Train_Mean_F1': 0.8964654037740368, 'CV_Train_Mean_Precision': 0.8798366055938729, 'CV_Train_Mean_Recall': 0.9137943072410613, 'CV_Train_Mean_ROC_AUC': 0.9669659272100029, 'CV_Val_Accuracy_Folds': [0.8687782805429864, 0.8717948717948718, 0.8657616892911011, 0.8564954682779456, 0.8625377643504532], 'CV_Val_Mean_Accuracy': 0.8650736148514715, 'CV_Val_Mean_F1': 0.870237780875498, 'CV_Val_Mean_Precision': 0.8504628507590193, 'CV_Val_Mean_Recall': 0.8912074325279074, 'CV_Val_Mean_ROC_AUC': 0.9301832374770141, 'Test_Accuracy': 0.8757539203860072, 'Test_F1': 0.8766467065868263, 'Test_Precision': 0.8840579710144928, 'Test_Recall': 0.8693586698337292, 'Test_ROC_AUC': 0.8758558055050999}
# Training svm with select_percentile_50 and none on standard...
# {'Fingerprint': 'standard', 'Classifier': 'svm', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.9007547169811321, 0.9007547169811321, 0.9022641509433962, 0.9000377216144851, 0.9000377216144851], 'CV_Train_Mean_Accuracy': 0.9007698056269261, 'CV_Train_Mean_F1': 0.9043145462158841, 'CV_Train_Mean_Precision': 0.8858995827144703, 'CV_Train_Mean_Recall': 0.9236041251235936, 'CV_Train_Mean_ROC_AUC': 0.9720776213364758, 'CV_Val_Accuracy_Folds': [0.8702865761689291, 0.8717948717948718, 0.8687782805429864, 0.850453172205438, 0.8580060422960725], 'CV_Val_Mean_Accuracy': 0.8638637886016596, 'CV_Val_Mean_F1': 0.8691512813387907, 'CV_Val_Mean_Precision': 0.8488541463976965, 'CV_Val_Mean_Recall': 0.890606895577222, 'CV_Val_Mean_ROC_AUC': 0.9317800959291962, 'Test_Accuracy': 0.8757539203860072, 'Test_F1': 0.8772348033373063, 'Test_Precision': 0.8803827751196173, 'Test_Recall': 0.8741092636579573, 'Test_ROC_AUC': 0.8757801220250571}
# Training lr with select_percentile_25 and pca on standard...
# {'Fingerprint': 'standard', 'Classifier': 'lr', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.8630188679245283, 0.860754716981132, 0.860754716981132, 0.8596755941154282, 0.8585439456808751], 'CV_Train_Mean_Accuracy': 0.8605495683366191, 'CV_Train_Mean_F1': 0.8653851303143417, 'CV_Train_Mean_Precision': 0.848575222323779, 'CV_Train_Mean_Recall': 0.8828777542712263, 'CV_Train_Mean_ROC_AUC': 0.9280997413931698, 'CV_Val_Accuracy_Folds': [0.832579185520362, 0.8491704374057315, 0.8416289592760181, 0.8444108761329305, 0.8444108761329305], 'CV_Val_Mean_Accuracy': 0.8424400668935945, 'CV_Val_Mean_F1': 0.8475478547065896, 'CV_Val_Mean_Precision': 0.8326479694052557, 'CV_Val_Mean_Recall': 0.8632648014695492, 'CV_Val_Mean_ROC_AUC': 0.9100266733927531, 'Test_Accuracy': 0.841978287092883, 'Test_F1': 0.8467836257309942, 'Test_Precision': 0.8341013824884793, 'Test_Recall': 0.8598574821852731, 'Test_ROC_AUC': 0.8416934469749895}
# Training lr with select_percentile_25 and none on standard...
# {'Fingerprint': 'standard', 'Classifier': 'lr', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.8875471698113208, 0.8852830188679245, 0.8935849056603774, 0.8887212372689551, 0.8890984534138061], 'CV_Train_Mean_Accuracy': 0.8888469570044768, 'CV_Train_Mean_F1': 0.8922672612382035, 'CV_Train_Mean_Precision': 0.878328074033319, 'CV_Train_Mean_Recall': 0.906658086468512, 'CV_Train_Mean_ROC_AUC': 0.9533070366081595, 'CV_Val_Accuracy_Folds': [0.8431372549019608, 0.8657616892911011, 0.8220211161387632, 0.8474320241691843, 0.8398791540785498], 'CV_Val_Mean_Accuracy': 0.8436462477159118, 'CV_Val_Mean_F1': 0.8489617056784043, 'CV_Val_Mean_Precision': 0.8330378584834074, 'CV_Val_Mean_Recall': 0.86562985728416, 'CV_Val_Mean_ROC_AUC': 0.9122385498418701, 'Test_Accuracy': 0.8576598311218335, 'Test_F1': 0.8595238095238096, 'Test_Precision': 0.8615751789976134, 'Test_Recall': 0.8574821852731591, 'Test_ROC_AUC': 0.8576626612640306}
# Training lr with select_percentile_50 and pca on standard...
# {'Fingerprint': 'standard', 'Classifier': 'lr', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.8784905660377359, 0.8732075471698113, 0.8811320754716981, 0.8766503206337232, 0.8728781591852132], 'CV_Train_Mean_Accuracy': 0.8764717336996364, 'CV_Train_Mean_F1': 0.8814526128196153, 'CV_Train_Mean_Precision': 0.859485629089075, 'CV_Train_Mean_Recall': 0.9045772963537841, 'CV_Train_Mean_ROC_AUC': 0.9387548090511888, 'CV_Val_Accuracy_Folds': [0.8536953242835595, 0.8582202111613876, 0.8446455505279035, 0.8685800604229608, 0.8580060422960725], 'CV_Val_Mean_Accuracy': 0.8566294377383766, 'CV_Val_Mean_F1': 0.8618378325224721, 'CV_Val_Mean_Precision': 0.8435455836444936, 'CV_Val_Mean_Recall': 0.8811060477603505, 'CV_Val_Mean_ROC_AUC': 0.9167796660108642, 'Test_Accuracy': 0.8576598311218335, 'Test_F1': 0.864367816091954, 'Test_Precision': 0.8374164810690423, 'Test_Recall': 0.8931116389548693, 'Test_ROC_AUC': 0.8570950351637091}
# Training lr with select_percentile_50 and none on standard...
# {'Fingerprint': 'standard', 'Classifier': 'lr', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.9256603773584906, 0.9249056603773584, 0.9256603773584906, 0.9253112033195021, 0.9215390418709921], 'CV_Train_Mean_Accuracy': 0.9246153320569668, 'CV_Train_Mean_F1': 0.9265386563443458, 'CV_Train_Mean_Precision': 0.9169187069831626, 'CV_Train_Mean_Recall': 0.9363865950054409, 'CV_Train_Mean_ROC_AUC': 0.9779024926447768, 'CV_Val_Accuracy_Folds': [0.8461538461538461, 0.8582202111613876, 0.8371040723981901, 0.8459214501510574, 0.8413897280966768], 'CV_Val_Mean_Accuracy': 0.8457578615922315, 'CV_Val_Mean_F1': 0.850075468941539, 'CV_Val_Mean_Precision': 0.8394072450436522, 'CV_Val_Mean_Recall': 0.8614720220432387, 'CV_Val_Mean_ROC_AUC': 0.9136162374289217, 'Test_Accuracy': 0.8612786489746683, 'Test_F1': 0.8619447779111644, 'Test_Precision': 0.8713592233009708, 'Test_Recall': 0.8527315914489311, 'Test_ROC_AUC': 0.8614148153323087}
# Training rf with select_percentile_25 and pca on standard...
# {'Fingerprint': 'standard', 'Classifier': 'rf', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.9577358490566038, 0.9539622641509434, 0.9550943396226416, 0.949453036589966, 0.9509619011693701], 'CV_Train_Mean_Accuracy': 0.9534414781179048, 'CV_Train_Mean_F1': 0.9542621148621084, 'CV_Train_Mean_Precision': 0.9519414884552996, 'CV_Train_Mean_Recall': 0.9565997006136868, 'CV_Train_Mean_ROC_AUC': 0.9914155271929792, 'CV_Val_Accuracy_Folds': [0.8748114630467572, 0.8687782805429864, 0.8536953242835595, 0.850453172205438, 0.8670694864048338], 'CV_Val_Mean_Accuracy': 0.862961545296715, 'CV_Val_Mean_F1': 0.8660720769998281, 'CV_Val_Mean_Precision': 0.8598174623801814, 'CV_Val_Mean_Recall': 0.8727638830012717, 'CV_Val_Mean_ROC_AUC': 0.92747516637577, 'Test_Accuracy': 0.8685162846803377, 'Test_F1': 0.8691476590636255, 'Test_Precision': 0.8786407766990292, 'Test_Recall': 0.8598574821852731, 'Test_ROC_AUC': 0.868654231288715}
# Training rf with select_percentile_25 and none on standard...
# {'Fingerprint': 'standard', 'Classifier': 'rf', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.900377358490566, 0.8981132075471698, 0.8969811320754717, 0.8962655601659751, 0.8962655601659751], 'CV_Train_Mean_Accuracy': 0.8976005636890315, 'CV_Train_Mean_F1': 0.9001073610412244, 'CV_Train_Mean_Precision': 0.8916597093602598, 'CV_Train_Mean_Recall': 0.9087407546523639, 'CV_Train_Mean_ROC_AUC': 0.9659736237408915, 'CV_Val_Accuracy_Folds': [0.8748114630467572, 0.8748114630467572, 0.8536953242835595, 0.8625377643504532, 0.8670694864048338], 'CV_Val_Mean_Accuracy': 0.8665851002264722, 'CV_Val_Mean_F1': 0.8704737890291578, 'CV_Val_Mean_Precision': 0.8586170098844448, 'CV_Val_Mean_Recall': 0.8828758654797231, 'CV_Val_Mean_ROC_AUC': 0.9300789680736317, 'Test_Accuracy': 0.8709288299155609, 'Test_F1': 0.8715486194477791, 'Test_Precision': 0.8810679611650486, 'Test_Recall': 0.8622327790973872, 'Test_ROC_AUC': 0.8710673699408504}
# Training rf with select_percentile_50 and pca on standard...
# {'Fingerprint': 'standard', 'Classifier': 'rf', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.9630188679245283, 0.9618867924528302, 0.9592452830188679, 0.957374575631837, 0.961523953225198], 'CV_Train_Mean_Accuracy': 0.9606098944506524, 'CV_Train_Mean_F1': 0.9614015311637681, 'CV_Train_Mean_Precision': 0.9565979295190715, 'CV_Train_Mean_Recall': 0.9662608196114606, 'CV_Train_Mean_ROC_AUC': 0.9935319894546002, 'CV_Val_Accuracy_Folds': [0.8733031674208145, 0.8808446455505279, 0.861236802413273, 0.8610271903323263, 0.8564954682779456], 'CV_Val_Mean_Accuracy': 0.8665814547989775, 'CV_Val_Mean_F1': 0.870268993508183, 'CV_Val_Mean_Precision': 0.860059122641769, 'CV_Val_Mean_Recall': 0.8810972163346051, 'CV_Val_Mean_ROC_AUC': 0.929899687554526, 'Test_Accuracy': 0.8636911942098915, 'Test_F1': 0.8640192539109507, 'Test_Precision': 0.875609756097561, 'Test_Recall': 0.8527315914489311, 'Test_ROC_AUC': 0.8638657957244655}
# Training rf with select_percentile_50 and none on standard...
# {'Fingerprint': 'standard', 'Classifier': 'rf', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.9086792452830189, 0.9056603773584906, 0.9022641509433962, 0.9038098830629951, 0.9041870992078461], 'CV_Train_Mean_Accuracy': 0.9049201511711493, 'CV_Train_Mean_F1': 0.907163495330804, 'CV_Train_Mean_Precision': 0.899385061695099, 'CV_Train_Mean_Recall': 0.9151327076785408, 'CV_Train_Mean_ROC_AUC': 0.9715905765816618, 'CV_Val_Accuracy_Folds': [0.8763197586726998, 0.8793363499245852, 0.8672699849170438, 0.851963746223565, 0.8610271903323263], 'CV_Val_Mean_Accuracy': 0.8671834060140441, 'CV_Val_Mean_F1': 0.8705821548529306, 'CV_Val_Mean_Precision': 0.8616295490399617, 'CV_Val_Mean_Recall': 0.8799014412886816, 'CV_Val_Mean_ROC_AUC': 0.9328799110004237, 'Test_Accuracy': 0.8685162846803377, 'Test_F1': 0.8685162846803377, 'Test_Precision': 0.8823529411764706, 'Test_Recall': 0.8551068883610451, 'Test_ROC_AUC': 0.8687299147687578}
# Training xgb with select_percentile_25 and pca on standard...
# {'Fingerprint': 'standard', 'Classifier': 'xgb', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.9611320754716981, 0.9566037735849057, 0.9584905660377359, 0.953979630328178, 0.953225198038476], 'CV_Train_Mean_Accuracy': 0.9566862486921988, 'CV_Train_Mean_F1': 0.9575752997143419, 'CV_Train_Mean_Precision': 0.9523670697274822, 'CV_Train_Mean_Recall': 0.9628428442804511, 'CV_Train_Mean_ROC_AUC': 0.9927104269197157, 'CV_Val_Accuracy_Folds': [0.8642533936651584, 0.8642533936651584, 0.8491704374057315, 0.8564954682779456, 0.8580060422960725], 'CV_Val_Mean_Accuracy': 0.8584357470620134, 'CV_Val_Mean_F1': 0.8632642056604837, 'CV_Val_Mean_Precision': 0.8475490607465946, 'CV_Val_Mean_Recall': 0.8799102727144271, 'CV_Val_Mean_ROC_AUC': 0.9297088654981053, 'Test_Accuracy': 0.8673100120627262, 'Test_F1': 0.8690476190476191, 'Test_Precision': 0.8711217183770883, 'Test_Recall': 0.8669833729216152, 'Test_ROC_AUC': 0.8673152158725723}
# Training xgb with select_percentile_25 and none on standard...
# {'Fingerprint': 'standard', 'Classifier': 'xgb', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.9143396226415095, 0.9135849056603773, 0.9135849056603773, 0.9117314221048661, 0.915126367408525], 'CV_Train_Mean_Accuracy': 0.913673444695131, 'CV_Train_Mean_F1': 0.9161774398463528, 'CV_Train_Mean_Precision': 0.9034767349675523, 'CV_Train_Mean_Recall': 0.9292511475554722, 'CV_Train_Mean_ROC_AUC': 0.972705226917492, 'CV_Val_Accuracy_Folds': [0.8717948717948718, 0.8763197586726998, 0.8597285067873304, 0.8459214501510574, 0.851963746223565], 'CV_Val_Mean_Accuracy': 0.8611456667259049, 'CV_Val_Mean_F1': 0.8664456253131757, 'CV_Val_Mean_Precision': 0.8471256250972795, 'CV_Val_Mean_Recall': 0.8870372332909426, 'CV_Val_Mean_ROC_AUC': 0.9332162531102572, 'Test_Accuracy': 0.8709288299155609, 'Test_F1': 0.8715486194477791, 'Test_Precision': 0.8810679611650486, 'Test_Recall': 0.8622327790973872, 'Test_ROC_AUC': 0.8710673699408504}
# Training xgb with select_percentile_50 and pca on standard...
# {'Fingerprint': 'standard', 'Classifier': 'xgb', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.9618867924528302, 0.96, 0.9569811320754718, 0.9588834402112411, 0.961146737080347], 'CV_Train_Mean_Accuracy': 0.9597796203639779, 'CV_Train_Mean_F1': 0.9606198685427019, 'CV_Train_Mean_Precision': 0.9550559078463744, 'CV_Train_Mean_Recall': 0.9662607091368063, 'CV_Train_Mean_ROC_AUC': 0.9937597365191426, 'CV_Val_Accuracy_Folds': [0.8748114630467572, 0.8582202111613876, 0.8446455505279035, 0.8429003021148036, 0.8595166163141994], 'CV_Val_Mean_Accuracy': 0.8560188286330103, 'CV_Val_Mean_F1': 0.8607245289159522, 'CV_Val_Mean_Precision': 0.8464936897826589, 'CV_Val_Mean_Recall': 0.8757471386180585, 'CV_Val_Mean_ROC_AUC': 0.9319109958978627, 'Test_Accuracy': 0.8624849215922799, 'Test_F1': 0.8646080760095012, 'Test_Precision': 0.8646080760095012, 'Test_Recall': 0.8646080760095012, 'Test_ROC_AUC': 0.86245109682828}
# Training xgb with select_percentile_50 and none on standard...
# {'Fingerprint': 'standard', 'Classifier': 'xgb', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.9211320754716981, 0.92, 0.9173584905660377, 0.9196529611467371, 0.9204073934364391], 'CV_Train_Mean_Accuracy': 0.9197101841241825, 'CV_Train_Mean_F1': 0.9220340542547252, 'CV_Train_Mean_Precision': 0.9092742796240604, 'CV_Train_Mean_Recall': 0.935196672503411, 'CV_Train_Mean_ROC_AUC': 0.977426124170862, 'CV_Val_Accuracy_Folds': [0.8717948717948718, 0.8717948717948718, 0.8748114630467572, 0.8549848942598187, 0.8625377643504532], 'CV_Val_Mean_Accuracy': 0.8671847730493545, 'CV_Val_Mean_F1': 0.8714773892836682, 'CV_Val_Mean_Precision': 0.8568943195655286, 'CV_Val_Mean_Recall': 0.887051363572135, 'CV_Val_Mean_ROC_AUC': 0.9366397201659536, 'Test_Accuracy': 0.8757539203860072, 'Test_F1': 0.8772348033373063, 'Test_Precision': 0.8803827751196173, 'Test_Recall': 0.8741092636579573, 'Test_ROC_AUC': 0.8757801220250571}
# Processing fingerprint DataFrame: df_extended.csv
# Training svm with select_percentile_25 and pca on extended...
# {'Fingerprint': 'extended', 'Classifier': 'svm', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.8962264150943396, 0.8928301886792452, 0.8920754716981132, 0.895888344021124, 0.8906073179932101], 'CV_Train_Mean_Accuracy': 0.8935255474972064, 'CV_Train_Mean_F1': 0.8969184263583367, 'CV_Train_Mean_Precision': 0.8819195590027592, 'CV_Train_Mean_Recall': 0.912456017278236, 'CV_Train_Mean_ROC_AUC': 0.9640490849506209, 'CV_Val_Accuracy_Folds': [0.8672699849170438, 0.8733031674208145, 0.861236802413273, 0.8549848942598187, 0.8731117824773413], 'CV_Val_Mean_Accuracy': 0.8659813262976582, 'CV_Val_Mean_F1': 0.8703681893555693, 'CV_Val_Mean_Precision': 0.8552236293343434, 'CV_Val_Mean_Recall': 0.886456125476897, 'CV_Val_Mean_ROC_AUC': 0.9258388127308859, 'Test_Accuracy': 0.8757539203860072, 'Test_F1': 0.8775267538644471, 'Test_Precision': 0.8785714285714286, 'Test_Recall': 0.8764845605700713, 'Test_ROC_AUC': 0.8757422802850356}
# Training svm with select_percentile_25 and none on extended...
# {'Fingerprint': 'extended', 'Classifier': 'svm', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.9030188679245283, 0.9, 0.8988679245283019, 0.9000377216144851, 0.8970199924556771], 'CV_Train_Mean_Accuracy': 0.8997889013045987, 'CV_Train_Mean_F1': 0.9030336651576107, 'CV_Train_Mean_Precision': 0.8874996043066832, 'CV_Train_Mean_Recall': 0.9191445947513491, 'CV_Train_Mean_ROC_AUC': 0.9686744297505948, 'CV_Val_Accuracy_Folds': [0.8702865761689291, 0.8748114630467572, 0.861236802413273, 0.8549848942598187, 0.8670694864048338], 'CV_Val_Mean_Accuracy': 0.8656778444587223, 'CV_Val_Mean_F1': 0.8703798907718431, 'CV_Val_Mean_Precision': 0.8536465251867507, 'CV_Val_Mean_Recall': 0.8882400734774623, 'CV_Val_Mean_ROC_AUC': 0.9268109691709905, 'Test_Accuracy': 0.879372738238842, 'Test_F1': 0.8803827751196173, 'Test_Precision': 0.8867469879518072, 'Test_Recall': 0.8741092636579573, 'Test_ROC_AUC': 0.8794565926132923}
# Training svm with select_percentile_50 and pca on extended...
# {'Fingerprint': 'extended', 'Classifier': 'svm', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.900377358490566, 0.8939622641509434, 0.8950943396226415, 0.8966427763108261, 0.8909845341380611], 'CV_Train_Mean_Accuracy': 0.8954122545426075, 'CV_Train_Mean_F1': 0.8988561679729775, 'CV_Train_Mean_Precision': 0.882897996246166, 'CV_Train_Mean_Recall': 0.9154295530747858, 'CV_Train_Mean_ROC_AUC': 0.9683515439806282, 'CV_Val_Accuracy_Folds': [0.8672699849170438, 0.8702865761689291, 0.8642533936651584, 0.8625377643504532, 0.8700906344410876], 'CV_Val_Mean_Accuracy': 0.8668876707085345, 'CV_Val_Mean_F1': 0.8715870726169481, 'CV_Val_Mean_Precision': 0.8541775000499321, 'CV_Val_Mean_Recall': 0.8900222551928783, 'CV_Val_Mean_ROC_AUC': 0.9308903077403377, 'Test_Accuracy': 0.879372738238842, 'Test_F1': 0.8803827751196173, 'Test_Precision': 0.8867469879518072, 'Test_Recall': 0.8741092636579573, 'Test_ROC_AUC': 0.8794565926132923}
# Training svm with select_percentile_50 and none on extended...
# {'Fingerprint': 'extended', 'Classifier': 'svm', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.9037735849056604, 0.9015094339622641, 0.9037735849056604, 0.901546586193889, 0.901546586193889], 'CV_Train_Mean_Accuracy': 0.9024299552322725, 'CV_Train_Mean_F1': 0.9056678543867648, 'CV_Train_Mean_Precision': 0.8894033893716949, 'CV_Train_Mean_Recall': 0.9225627910316676, 'CV_Train_Mean_ROC_AUC': 0.9720386808459285, 'CV_Val_Accuracy_Folds': [0.8642533936651584, 0.8717948717948718, 0.861236802413273, 0.8549848942598187, 0.8625377643504532], 'CV_Val_Mean_Accuracy': 0.862961545296715, 'CV_Val_Mean_F1': 0.8684820064923529, 'CV_Val_Mean_Precision': 0.8471333530734722, 'CV_Val_Mean_Recall': 0.8912109650982055, 'CV_Val_Mean_ROC_AUC': 0.9303879175699107, 'Test_Accuracy': 0.8805790108564535, 'Test_F1': 0.882282996432818, 'Test_Precision': 0.8833333333333333, 'Test_Recall': 0.8812351543942993, 'Test_ROC_AUC': 0.8805685575893065}
# Training lr with select_percentile_25 and pca on extended...
# {'Fingerprint': 'extended', 'Classifier': 'lr', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.8584905660377359, 0.859622641509434, 0.8535849056603774, 0.8577895133911732, 0.8555262165220672], 'CV_Train_Mean_Accuracy': 0.8570027686241575, 'CV_Train_Mean_F1': 0.8615187469081338, 'CV_Train_Mean_Precision': 0.8473535601380101, 'CV_Train_Mean_Recall': 0.8761907234432741, 'CV_Train_Mean_ROC_AUC': 0.9263446736025006, 'CV_Val_Accuracy_Folds': [0.8416289592760181, 0.832579185520362, 0.8280542986425339, 0.8368580060422961, 0.8353474320241692], 'CV_Val_Mean_Accuracy': 0.8348935763010757, 'CV_Val_Mean_F1': 0.8406662455083816, 'CV_Val_Mean_Precision': 0.824491232870767, 'CV_Val_Mean_Recall': 0.8579129574678536, 'CV_Val_Mean_ROC_AUC': 0.9068893967814479, 'Test_Accuracy': 0.8335343787696019, 'Test_F1': 0.8395348837209302, 'Test_Precision': 0.8223234624145785, 'Test_Recall': 0.8574821852731591, 'Test_ROC_AUC': 0.8331528573424619}
# Training lr with select_percentile_25 and none on extended...
# {'Fingerprint': 'extended', 'Classifier': 'lr', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.8781132075471698, 0.8754716981132076, 0.8754716981132076, 0.8792908336476801, 0.8766503206337232], 'CV_Train_Mean_Accuracy': 0.8769995516109976, 'CV_Train_Mean_F1': 0.8808314208607347, 'CV_Train_Mean_Precision': 0.8667769556269185, 'CV_Train_Mean_Recall': 0.8953629368582113, 'CV_Train_Mean_ROC_AUC': 0.9479399831433459, 'CV_Val_Accuracy_Folds': [0.8280542986425339, 0.8416289592760181, 0.8371040723981901, 0.8293051359516617, 0.823262839879154], 'CV_Val_Mean_Accuracy': 0.8318710612295115, 'CV_Val_Mean_F1': 0.8381342848944049, 'CV_Val_Mean_Precision': 0.8199124041668803, 'CV_Val_Mean_Recall': 0.8573159530874666, 'CV_Val_Mean_ROC_AUC': 0.9055251468430109, 'Test_Accuracy': 0.8528347406513872, 'Test_F1': 0.8574766355140186, 'Test_Precision': 0.8436781609195402, 'Test_Recall': 0.8717339667458432, 'Test_ROC_AUC': 0.8525336500395884}
# Training lr with select_percentile_50 and pca on extended...
# {'Fingerprint': 'extended', 'Classifier': 'lr', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.8694339622641509, 0.8735849056603774, 0.869056603773585, 0.8691059977367032, 0.8642021878536401], 'CV_Train_Mean_Accuracy': 0.8690767314576913, 'CV_Train_Mean_F1': 0.8737946495977127, 'CV_Train_Mean_Precision': 0.8556952962716318, 'CV_Train_Mean_Recall': 0.8926880140523761, 'CV_Train_Mean_ROC_AUC': 0.9406711602916575, 'CV_Val_Accuracy_Folds': [0.8371040723981901, 0.8446455505279035, 0.8416289592760181, 0.850453172205438, 0.8413897280966768], 'CV_Val_Mean_Accuracy': 0.8430442965008453, 'CV_Val_Mean_F1': 0.8484127025190065, 'CV_Val_Mean_Precision': 0.8326237993969521, 'CV_Val_Mean_Recall': 0.8650487494701145, 'CV_Val_Mean_ROC_AUC': 0.917056410329074, 'Test_Accuracy': 0.8624849215922799, 'Test_F1': 0.8677494199535963, 'Test_Precision': 0.8480725623582767, 'Test_Recall': 0.8883610451306413, 'Test_ROC_AUC': 0.8620726794280658}
# Training lr with select_percentile_50 and none on extended...
# {'Fingerprint': 'extended', 'Classifier': 'lr', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.92, 0.9211320754716981, 0.9218867924528302, 0.9200301772915881, 0.9155035835533761], 'CV_Train_Mean_Accuracy': 0.9197105257538987, 'CV_Train_Mean_F1': 0.9217643758056321, 'CV_Train_Mean_Precision': 0.9121082098550255, 'CV_Train_Mean_Recall': 0.9316291144904081, 'CV_Train_Mean_ROC_AUC': 0.9762066517550501, 'CV_Val_Accuracy_Folds': [0.8371040723981901, 0.8340874811463047, 0.8340874811463047, 0.8489425981873112, 0.8217522658610272], 'CV_Val_Mean_Accuracy': 0.8351947797478276, 'CV_Val_Mean_F1': 0.8399415585581126, 'CV_Val_Mean_Precision': 0.8291772639596061, 'CV_Val_Mean_Recall': 0.8513671047053837, 'CV_Val_Mean_ROC_AUC': 0.9121243353709666, 'Test_Accuracy': 0.873341375150784, 'Test_F1': 0.8777648428405123, 'Test_Precision': 0.860730593607306, 'Test_Recall': 0.8954869358669834, 'Test_ROC_AUC': 0.8729885659727074}
# Training rf with select_percentile_25 and pca on extended...
# {'Fingerprint': 'extended', 'Classifier': 'rf', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.9607547169811321, 0.9607547169811321, 0.9528301886792453, 0.955488494907582, 0.9566201433421351], 'CV_Train_Mean_Accuracy': 0.9572896521782454, 'CV_Train_Mean_F1': 0.958080742155081, 'CV_Train_Mean_Precision': 0.9548324281607539, 'CV_Train_Mean_Recall': 0.9613564078061391, 'CV_Train_Mean_ROC_AUC': 0.9920715436659613, 'CV_Val_Accuracy_Folds': [0.8672699849170438, 0.8748114630467572, 0.8491704374057315, 0.851963746223565, 0.8534743202416919], 'CV_Val_Mean_Accuracy': 0.8593379903669579, 'CV_Val_Mean_F1': 0.8625000856647962, 'CV_Val_Mean_Precision': 0.8569662070063705, 'CV_Val_Mean_Recall': 0.8686078140454996, 'CV_Val_Mean_ROC_AUC': 0.9254574217090339, 'Test_Accuracy': 0.856453558504222, 'Test_F1': 0.859504132231405, 'Test_Precision': 0.8544600938967136, 'Test_Recall': 0.8646080760095012, 'Test_ROC_AUC': 0.8563236458478879}
# Training rf with select_percentile_25 and none on extended...
# {'Fingerprint': 'extended', 'Classifier': 'rf', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.9007547169811321, 0.9022641509433962, 0.899245283018868, 0.9000377216144851, 0.8973972086005281], 'CV_Train_Mean_Accuracy': 0.8999398162316818, 'CV_Train_Mean_F1': 0.9022759478583572, 'CV_Train_Mean_Precision': 0.8947937974049083, 'CV_Train_Mean_Recall': 0.9099301247811221, 'CV_Train_Mean_ROC_AUC': 0.9664346052277655, 'CV_Val_Accuracy_Folds': [0.8702865761689291, 0.8778280542986425, 0.8506787330316742, 0.8489425981873112, 0.8595166163141994], 'CV_Val_Mean_Accuracy': 0.8614505156001513, 'CV_Val_Mean_F1': 0.8654577706481403, 'CV_Val_Mean_Precision': 0.854021702996695, 'CV_Val_Mean_Recall': 0.8775240214780273, 'CV_Val_Mean_ROC_AUC': 0.9283750404683794, 'Test_Accuracy': 0.873341375150784, 'Test_F1': 0.8739495798319328, 'Test_Precision': 0.883495145631068, 'Test_Recall': 0.8646080760095012, 'Test_ROC_AUC': 0.8734805085929859}
# Training rf with select_percentile_50 and pca on extended...
# {'Fingerprint': 'extended', 'Classifier': 'rf', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.9645283018867925, 0.9652830188679246, 0.9615094339622642, 0.959260656356092, 0.961523953225198], 'CV_Train_Mean_Accuracy': 0.9624210728596543, 'CV_Train_Mean_F1': 0.9631276215836465, 'CV_Train_Mean_Precision': 0.9595821811963805, 'CV_Train_Mean_Recall': 0.9667069162657358, 'CV_Train_Mean_ROC_AUC': 0.9936137031378477, 'CV_Val_Accuracy_Folds': [0.8687782805429864, 0.8778280542986425, 0.8657616892911011, 0.8549848942598187, 0.8670694864048338], 'CV_Val_Mean_Accuracy': 0.8668844809594765, 'CV_Val_Mean_F1': 0.8704084665770371, 'CV_Val_Mean_Precision': 0.8608617068552634, 'CV_Val_Mean_Recall': 0.8805055108096651, 'CV_Val_Mean_ROC_AUC': 0.9272664897151894, 'Test_Accuracy': 0.8600723763570567, 'Test_F1': 0.8602409638554217, 'Test_Precision': 0.8728606356968215, 'Test_Recall': 0.8479809976247031, 'Test_ROC_AUC': 0.8602650086162731}
# Training rf with select_percentile_50 and none on extended...
# {'Fingerprint': 'extended', 'Classifier': 'rf', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.9105660377358491, 0.9071698113207547, 0.9079245283018867, 0.90946812523576, 0.9060731799321011], 'CV_Train_Mean_Accuracy': 0.9082403365052704, 'CV_Train_Mean_F1': 0.910318704454309, 'CV_Train_Mean_Precision': 0.9034165770573928, 'CV_Train_Mean_Recall': 0.9173614233554467, 'CV_Train_Mean_ROC_AUC': 0.9720407704745156, 'CV_Val_Accuracy_Folds': [0.8717948717948718, 0.8838612368024132, 0.8627450980392157, 0.8564954682779456, 0.8610271903323263], 'CV_Val_Mean_Accuracy': 0.8671847730493546, 'CV_Val_Mean_F1': 0.8702791961222172, 'CV_Val_Mean_Precision': 0.8633760982137663, 'CV_Val_Mean_Recall': 0.8775222551928785, 'CV_Val_Mean_ROC_AUC': 0.9319611876933461, 'Test_Accuracy': 0.8721351025331725, 'Test_F1': 0.8719806763285024, 'Test_Precision': 0.8869778869778869, 'Test_Recall': 0.8574821852731591, 'Test_ROC_AUC': 0.8723685436169717}
# Training xgb with select_percentile_25 and pca on extended...
# {'Fingerprint': 'extended', 'Classifier': 'xgb', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.9554716981132075, 0.9581132075471698, 0.9535849056603773, 0.951339117314221, 0.953225198038476], 'CV_Train_Mean_Accuracy': 0.9543468253346903, 'CV_Train_Mean_F1': 0.9554644718043427, 'CV_Train_Mean_Precision': 0.9464945392918199, 'CV_Train_Mean_Recall': 0.9646263471003165, 'CV_Train_Mean_ROC_AUC': 0.9916868124857421, 'CV_Val_Accuracy_Folds': [0.8627450980392157, 0.8597285067873304, 0.8491704374057315, 0.8489425981873112, 0.8534743202416919], 'CV_Val_Mean_Accuracy': 0.8548121921322561, 'CV_Val_Mean_F1': 0.8593452216972798, 'CV_Val_Mean_Precision': 0.845833478148813, 'CV_Val_Mean_Recall': 0.8739578917620461, 'CV_Val_Mean_ROC_AUC': 0.9260967509222295, 'Test_Accuracy': 0.8455971049457177, 'Test_F1': 0.8486997635933806, 'Test_Precision': 0.8447058823529412, 'Test_Recall': 0.8527315914489311, 'Test_ROC_AUC': 0.8454834427832891}
# Training xgb with select_percentile_25 and none on extended...
# {'Fingerprint': 'extended', 'Classifier': 'xgb', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.9184905660377358, 0.9192452830188679, 0.9207547169811321, 0.918898528857035, 0.9204073934364391], 'CV_Train_Mean_Accuracy': 0.919559297666242, 'CV_Train_Mean_F1': 0.9215728855697829, 'CV_Train_Mean_Precision': 0.9124643388534667, 'CV_Train_Mean_Recall': 0.9308865038638512, 'CV_Train_Mean_ROC_AUC': 0.9757895800228307, 'CV_Val_Accuracy_Folds': [0.8702865761689291, 0.8672699849170438, 0.8763197586726998, 0.8444108761329305, 0.8595166163141994], 'CV_Val_Mean_Accuracy': 0.8635607624411605, 'CV_Val_Mean_F1': 0.8672923090532058, 'CV_Val_Mean_Precision': 0.8565176020020908, 'CV_Val_Mean_Recall': 0.8787250953793979, 'CV_Val_Mean_ROC_AUC': 0.9307109668024897, 'Test_Accuracy': 0.8673100120627262, 'Test_F1': 0.8690476190476191, 'Test_Precision': 0.8711217183770883, 'Test_Recall': 0.8669833729216152, 'Test_ROC_AUC': 0.8673152158725723}
# Training xgb with select_percentile_50 and pca on extended...
# {'Fingerprint': 'extended', 'Classifier': 'xgb', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.9520754716981132, 0.96, 0.9528301886792453, 0.952093549603923, 0.955111278762731], 'CV_Train_Mean_Accuracy': 0.9544220977488024, 'CV_Train_Mean_F1': 0.9555237874572485, 'CV_Train_Mean_Precision': 0.9468806273970266, 'CV_Train_Mean_Recall': 0.9643285074321823, 'CV_Train_Mean_ROC_AUC': 0.9925452748044895, 'CV_Val_Accuracy_Folds': [0.8702865761689291, 0.8717948717948718, 0.8536953242835595, 0.8413897280966768, 0.8489425981873112], 'CV_Val_Mean_Accuracy': 0.8572218197062696, 'CV_Val_Mean_F1': 0.8623177678440268, 'CV_Val_Mean_Precision': 0.8447124639977058, 'CV_Val_Mean_Recall': 0.8810830860534125, 'CV_Val_Mean_ROC_AUC': 0.9268098168738117, 'Test_Accuracy': 0.8588661037394452, 'Test_F1': 0.8608799048751486, 'Test_Precision': 0.861904761904762, 'Test_Recall': 0.8598574821852731, 'Test_ROC_AUC': 0.8588503097200876}
# Training xgb with select_percentile_50 and none on extended...
# {'Fingerprint': 'extended', 'Classifier': 'xgb', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.9264150943396227, 0.9290566037735849, 0.9275471698113208, 0.9222934741606941, 0.9298377970577141], 'CV_Train_Mean_Accuracy': 0.9270300278285873, 'CV_Train_Mean_F1': 0.9287201650752497, 'CV_Train_Mean_Precision': 0.9213365509205991, 'CV_Train_Mean_Recall': 0.9362367913741391, 'CV_Train_Mean_ROC_AUC': 0.9802098523911706, 'CV_Val_Accuracy_Folds': [0.8763197586726998, 0.8748114630467572, 0.8687782805429864, 0.8580060422960725, 0.8655589123867069], 'CV_Val_Mean_Accuracy': 0.8686948913890445, 'CV_Val_Mean_F1': 0.8720148031913583, 'CV_Val_Mean_Precision': 0.8634748130496293, 'CV_Val_Mean_Recall': 0.8810989826197542, 'CV_Val_Mean_ROC_AUC': 0.9337037364616585, 'Test_Accuracy': 0.8709288299155609, 'Test_F1': 0.8718562874251496, 'Test_Precision': 0.8792270531400966, 'Test_Recall': 0.8646080760095012, 'Test_ROC_AUC': 0.871029528200829}
# Processing fingerprint DataFrame: df_graph.csv
# Training svm with select_percentile_25 and pca on graph...
# {'Fingerprint': 'graph', 'Classifier': 'svm', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.8554716981132076, 0.8562264150943396, 0.8611320754716981, 0.8611844586948322, 0.8562806488117691], 'CV_Train_Mean_Accuracy': 0.8580590592371692, 'CV_Train_Mean_F1': 0.8631692517634726, 'CV_Train_Mean_Precision': 0.8453472068426457, 'CV_Train_Mean_Recall': 0.8818370830272265, 'CV_Train_Mean_ROC_AUC': 0.9302588409682814, 'CV_Val_Accuracy_Folds': [0.8386123680241327, 0.8386123680241327, 0.8099547511312217, 0.851963746223565, 0.8489425981873112], 'CV_Val_Mean_Accuracy': 0.8376171663180727, 'CV_Val_Mean_F1': 0.8428409992268996, 'CV_Val_Mean_Precision': 0.8289289130687557, 'CV_Val_Mean_Recall': 0.8573194856577645, 'CV_Val_Mean_ROC_AUC': 0.9025649933137453, 'Test_Accuracy': 0.850422195416164, 'Test_F1': 0.8548009367681498, 'Test_Precision': 0.8429561200923787, 'Test_Recall': 0.8669833729216152, 'Test_ROC_AUC': 0.8501583531274743}
# Training svm with select_percentile_25 and none on graph...
# {'Fingerprint': 'graph', 'Classifier': 'svm', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.870188679245283, 0.8679245283018868, 0.870188679245283, 0.8702376461712561, 0.8668427008675972], 'CV_Train_Mean_Accuracy': 0.8690764467662613, 'CV_Train_Mean_F1': 0.8742260635213818, 'CV_Train_Mean_Precision': 0.8532786743625819, 'CV_Train_Mean_Recall': 0.8962549092174529, 'CV_Train_Mean_ROC_AUC': 0.9379560520873731, 'CV_Val_Accuracy_Folds': [0.8476621417797888, 0.8521870286576169, 0.8280542986425339, 0.8549848942598187, 0.8534743202416919], 'CV_Val_Mean_Accuracy': 0.84727253671629, 'CV_Val_Mean_F1': 0.8526627266723705, 'CV_Val_Mean_Precision': 0.8358500230921138, 'CV_Val_Mean_Recall': 0.8704005934718101, 'CV_Val_Mean_ROC_AUC': 0.905983050882994, 'Test_Accuracy': 0.8624849215922799, 'Test_F1': 0.8671328671328671, 'Test_Precision': 0.851258581235698, 'Test_Recall': 0.8836104513064132, 'Test_ROC_AUC': 0.8621483629081085}
# Training svm with select_percentile_50 and pca on graph...
# {'Fingerprint': 'graph', 'Classifier': 'svm', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.8728301886792453, 0.8766037735849057, 0.8732075471698113, 0.8725009430403621, 0.8675971331572991], 'CV_Train_Mean_Accuracy': 0.8725479171263247, 'CV_Train_Mean_F1': 0.8767894207144252, 'CV_Train_Mean_Precision': 0.8609797579517615, 'CV_Train_Mean_Recall': 0.8932845771858791, 'CV_Train_Mean_ROC_AUC': 0.9449192776140022, 'CV_Val_Accuracy_Folds': [0.8416289592760181, 0.8552036199095022, 0.8310708898944194, 0.8534743202416919, 0.8549848942598187], 'CV_Val_Mean_Accuracy': 0.8472725367162901, 'CV_Val_Mean_F1': 0.8522934433575025, 'CV_Val_Mean_Precision': 0.8372017561211849, 'CV_Val_Mean_Recall': 0.8680161085205595, 'CV_Val_Mean_ROC_AUC': 0.9161942000196882, 'Test_Accuracy': 0.8709288299155609, 'Test_F1': 0.8751458576429405, 'Test_Precision': 0.8600917431192661, 'Test_Recall': 0.8907363420427553, 'Test_ROC_AUC': 0.8706132690605933}
# Training svm with select_percentile_50 and none on graph...
# {'Fingerprint': 'graph', 'Classifier': 'svm', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.8716981132075472, 0.8773584905660378, 0.8735849056603774, 0.8751414560543191, 0.8683515654470011], 'CV_Train_Mean_Accuracy': 0.8732269061870565, 'CV_Train_Mean_F1': 0.8775334238107693, 'CV_Train_Mean_Precision': 0.8611551504333125, 'CV_Train_Mean_Recall': 0.8946218728768152, 'CV_Train_Mean_ROC_AUC': 0.9486116467005739, 'CV_Val_Accuracy_Folds': [0.8431372549019608, 0.8536953242835595, 0.8371040723981901, 0.8595166163141994, 0.8534743202416919], 'CV_Val_Mean_Accuracy': 0.8493855176279203, 'CV_Val_Mean_F1': 0.8542793047121853, 'CV_Val_Mean_Precision': 0.8394010235672699, 'CV_Val_Mean_Recall': 0.8698018228062738, 'CV_Val_Mean_ROC_AUC': 0.9161656383991506, 'Test_Accuracy': 0.8709288299155609, 'Test_F1': 0.8760139049826188, 'Test_Precision': 0.8552036199095022, 'Test_Recall': 0.8978622327790974, 'Test_ROC_AUC': 0.870499743840529}
# Training lr with select_percentile_25 and pca on graph...
# {'Fingerprint': 'graph', 'Classifier': 'lr', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.8090566037735849, 0.8188679245283019, 0.8143396226415094, 0.8155413051678612, 0.8125235760090532], 'CV_Train_Mean_Accuracy': 0.8140658064240622, 'CV_Train_Mean_F1': 0.8209674587432418, 'CV_Train_Mean_Precision': 0.8031620954955683, 'CV_Train_Mean_Recall': 0.8396257118710541, 'CV_Train_Mean_ROC_AUC': 0.889743335665198, 'CV_Val_Accuracy_Folds': [0.8114630467571644, 0.7888386123680241, 0.7858220211161387, 0.8157099697885196, 0.8217522658610272], 'CV_Val_Mean_Accuracy': 0.8047171831781748, 'CV_Val_Mean_F1': 0.8122748557966826, 'CV_Val_Mean_Precision': 0.7938725195874257, 'CV_Val_Mean_Recall': 0.8317595732655081, 'CV_Val_Mean_ROC_AUC': 0.8769630771952841, 'Test_Accuracy': 0.8082026537997588, 'Test_F1': 0.8157589803012746, 'Test_Precision': 0.7963800904977375, 'Test_Recall': 0.836104513064133, 'Test_ROC_AUC': 0.8077581388850077}
# Training lr with select_percentile_25 and none on graph...
# {'Fingerprint': 'graph', 'Classifier': 'lr', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.8656603773584906, 0.8573584905660377, 0.8611320754716981, 0.8638249717087891, 0.8608072425499811], 'CV_Train_Mean_Accuracy': 0.8617566315309994, 'CV_Train_Mean_F1': 0.8668782040926736, 'CV_Train_Mean_Precision': 0.8480326238364061, 'CV_Train_Mean_Recall': 0.8865940111689875, 'CV_Train_Mean_ROC_AUC': 0.9335695022851859, 'CV_Val_Accuracy_Folds': [0.8129713423831071, 0.8280542986425339, 0.8386123680241327, 0.8383685800604229, 0.8489425981873112], 'CV_Val_Mean_Accuracy': 0.8333898374595016, 'CV_Val_Mean_F1': 0.8401601186415002, 'CV_Val_Mean_Precision': 0.8189882630145406, 'CV_Val_Mean_Recall': 0.8626819273703547, 'CV_Val_Mean_ROC_AUC': 0.8983559398794669, 'Test_Accuracy': 0.8407720144752714, 'Test_F1': 0.847926267281106, 'Test_Precision': 0.8232662192393736, 'Test_Recall': 0.8741092636579573, 'Test_ROC_AUC': 0.8402409063387826}
# Training lr with select_percentile_50 and pca on graph...
# {'Fingerprint': 'graph', 'Classifier': 'lr', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.8271698113207547, 0.8339622641509434, 0.8335849056603774, 0.8238400603545831, 0.8261033572236892], 'CV_Train_Mean_Accuracy': 0.8289320797420696, 'CV_Train_Mean_F1': 0.8339031223441011, 'CV_Train_Mean_Precision': 0.822290967955095, 'CV_Train_Mean_Recall': 0.84586940791109, 'CV_Train_Mean_ROC_AUC': 0.9058760574156051, 'CV_Val_Accuracy_Folds': [0.8235294117647058, 0.8024132730015083, 0.8114630467571644, 0.8353474320241692, 0.8368580060422961], 'CV_Val_Mean_Accuracy': 0.8219222339179687, 'CV_Val_Mean_F1': 0.8268138636992844, 'CV_Val_Mean_Precision': 0.816828405349949, 'CV_Val_Mean_Recall': 0.8371096509820546, 'CV_Val_Mean_ROC_AUC': 0.89242034629915, 'Test_Accuracy': 0.8323281061519904, 'Test_F1': 0.8381839348079162, 'Test_Precision': 0.821917808219178, 'Test_Recall': 0.8551068883610451, 'Test_ROC_AUC': 0.8319652088864049}
# Training lr with select_percentile_50 and none on graph...
# {'Fingerprint': 'graph', 'Classifier': 'lr', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.8905660377358491, 0.890188679245283, 0.8830188679245283, 0.8849490758204451, 0.8826857789513392], 'CV_Train_Mean_Accuracy': 0.886281687935489, 'CV_Train_Mean_F1': 0.8894156222357161, 'CV_Train_Mean_Precision': 0.8784156112085242, 'CV_Train_Mean_Recall': 0.9007142186403885, 'CV_Train_Mean_ROC_AUC': 0.9577579110514556, 'CV_Val_Accuracy_Folds': [0.8265460030165912, 0.8295625942684767, 0.8371040723981901, 0.851963746223565, 0.8564954682779456], 'CV_Val_Mean_Accuracy': 0.8403343768369538, 'CV_Val_Mean_F1': 0.8458927915929101, 'CV_Val_Mean_Precision': 0.8289778931611019, 'CV_Val_Mean_Recall': 0.8638830012717253, 'CV_Val_Mean_ROC_AUC': 0.9088342289993967, 'Test_Accuracy': 0.8528347406513872, 'Test_F1': 0.8594470046082949, 'Test_Precision': 0.8344519015659956, 'Test_Recall': 0.8859857482185273, 'Test_ROC_AUC': 0.8523065995994598}
# Training rf with select_percentile_25 and pca on graph...
# {'Fingerprint': 'graph', 'Classifier': 'rf', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.930566037735849, 0.9256603773584906, 0.9275471698113208, 0.9256884194643531, 0.926442851754055], 'CV_Train_Mean_Accuracy': 0.9271809712248137, 'CV_Train_Mean_F1': 0.9291871728475855, 'CV_Train_Mean_Precision': 0.917700785834971, 'CV_Train_Mean_Recall': 0.9409932776172827, 'CV_Train_Mean_ROC_AUC': 0.9783014079085823, 'CV_Val_Accuracy_Folds': [0.8416289592760181, 0.8340874811463047, 0.8386123680241327, 0.8459214501510574, 0.8625377643504532], 'CV_Val_Mean_Accuracy': 0.8445576045895932, 'CV_Val_Mean_F1': 0.8473297312898177, 'CV_Val_Mean_Precision': 0.8451319759018505, 'CV_Val_Mean_Recall': 0.8502066553624417, 'CV_Val_Mean_ROC_AUC': 0.9118306399047263, 'Test_Accuracy': 0.850422195416164, 'Test_F1': 0.8541176470588235, 'Test_Precision': 0.8461538461538461, 'Test_Recall': 0.8622327790973872, 'Test_ROC_AUC': 0.8502340366075172}
# Training rf with select_percentile_25 and none on graph...
# {'Fingerprint': 'graph', 'Classifier': 'rf', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.8705660377358491, 0.8713207547169811, 0.8754716981132076, 0.8736325914749151, 0.8691059977367032], 'CV_Train_Mean_Accuracy': 0.8720194159555312, 'CV_Train_Mean_F1': 0.8753333474515028, 'CV_Train_Mean_Precision': 0.8659777795678123, 'CV_Train_Mean_Recall': 0.8849574396394108, 'CV_Train_Mean_ROC_AUC': 0.9436562959016284, 'CV_Val_Accuracy_Folds': [0.8446455505279035, 0.8491704374057315, 0.8280542986425339, 0.8413897280966768, 0.8489425981873112], 'CV_Val_Mean_Accuracy': 0.8424405225720314, 'CV_Val_Mean_F1': 0.8461488112796388, 'CV_Val_Mean_Precision': 0.8391541817814234, 'CV_Val_Mean_Recall': 0.8537568885120814, 'CV_Val_Mean_ROC_AUC': 0.9121708428906787, 'Test_Accuracy': 0.8600723763570567, 'Test_F1': 0.8641686182669789, 'Test_Precision': 0.8521939953810623, 'Test_Recall': 0.8764845605700713, 'Test_ROC_AUC': 0.859810907736016}
# Training rf with select_percentile_50 and pca on graph...
# {'Fingerprint': 'graph', 'Classifier': 'rf', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.9430188679245283, 0.9426415094339623, 0.9441509433962264, 0.9377593360995851, 0.938136552244436], 'CV_Train_Mean_Accuracy': 0.9411414418197476, 'CV_Train_Mean_F1': 0.9426063141385154, 'CV_Train_Mean_Precision': 0.9334095699606507, 'CV_Train_Mean_Recall': 0.9519919132553014, 'CV_Train_Mean_ROC_AUC': 0.9847046760134439, 'CV_Val_Accuracy_Folds': [0.8431372549019608, 0.8642533936651584, 0.8386123680241327, 0.8474320241691843, 0.8700906344410876], 'CV_Val_Mean_Accuracy': 0.8527051350403049, 'CV_Val_Mean_F1': 0.8543701924634327, 'CV_Val_Mean_Precision': 0.8572771850228289, 'CV_Val_Mean_Recall': 0.8519764730818142, 'CV_Val_Mean_ROC_AUC': 0.9160155937167526, 'Test_Accuracy': 0.8685162846803377, 'Test_F1': 0.8713105076741441, 'Test_Precision': 0.8661971830985915, 'Test_Recall': 0.8764845605700713, 'Test_ROC_AUC': 0.8683893391085651}
# Training rf with select_percentile_50 and none on graph...
# {'Fingerprint': 'graph', 'Classifier': 'rf', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.8788679245283019, 0.8841509433962265, 0.88, 0.8781591852131271, 0.8774047529234251], 'CV_Train_Mean_Accuracy': 0.8797165612122161, 'CV_Train_Mean_F1': 0.8829535800268185, 'CV_Train_Mean_Precision': 0.8726236189319806, 'CV_Train_Mean_Recall': 0.8935795445130001, 'CV_Train_Mean_ROC_AUC': 0.9518883711617093, 'CV_Val_Accuracy_Folds': [0.8431372549019608, 0.8491704374057315, 0.8340874811463047, 0.850453172205438, 0.8655589123867069], 'CV_Val_Mean_Accuracy': 0.8484814516092284, 'CV_Val_Mean_F1': 0.8517442140060624, 'CV_Val_Mean_Precision': 0.8459637874892623, 'CV_Val_Mean_Recall': 0.8579217888935989, 'CV_Val_Mean_ROC_AUC': 0.9177187483299308, 'Test_Accuracy': 0.8685162846803377, 'Test_F1': 0.8731082654249127, 'Test_Precision': 0.8561643835616438, 'Test_Recall': 0.8907363420427553, 'Test_ROC_AUC': 0.8681622886684366}
# Training xgb with select_percentile_25 and pca on graph...
# ...
# Training svm with select_percentile_25 and none on fp2...
# {'Fingerprint': 'fp2', 'Classifier': 'svm', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.8822641509433963, 0.8852830188679245, 0.8875471698113208, 0.8853262919652961, 0.8838174273858921], 'CV_Train_Mean_Accuracy': 0.8848476117947659, 'CV_Train_Mean_F1': 0.8882103275861668, 'CV_Train_Mean_Precision': 0.8758391397222255, 'CV_Train_Mean_Recall': 0.9010112849859422, 'CV_Train_Mean_ROC_AUC': 0.9555064953289719, 'CV_Val_Accuracy_Folds': [0.8536953242835595, 0.8597285067873304, 0.8491704374057315, 0.8489425981873112, 0.8534743202416919], 'CV_Val_Mean_Accuracy': 0.8530022373811249, 'CV_Val_Mean_F1': 0.8575373724746619, 'CV_Val_Mean_Precision': 0.8442521669558385, 'CV_Val_Mean_Recall': 0.8715875370919882, 'CV_Val_Mean_ROC_AUC': 0.9168240263248482, 'Test_Accuracy': 0.8697225572979493, 'Test_F1': 0.8708133971291866, 'Test_Precision': 0.8771084337349397, 'Test_Recall': 0.8646080760095012, 'Test_ROC_AUC': 0.8698040380047506}
# Training svm with select_percentile_50 and pca on fp2...
# {'Fingerprint': 'fp2', 'Classifier': 'svm', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.8890566037735849, 0.8860377358490567, 0.8890566037735849, 0.8868351565447001, 0.8834402112410411], 'CV_Train_Mean_Accuracy': 0.8868852622363935, 'CV_Train_Mean_F1': 0.8906585217170033, 'CV_Train_Mean_Precision': 0.8745556231755043, 'CV_Train_Mean_Recall': 0.9074018018416125, 'CV_Train_Mean_ROC_AUC': 0.958226735935128, 'CV_Val_Accuracy_Folds': [0.8627450980392157, 0.8687782805429864, 0.8597285067873304, 0.8564954682779456, 0.8640483383685801], 'CV_Val_Mean_Accuracy': 0.8623591384032115, 'CV_Val_Mean_F1': 0.8669587538579684, 'CV_Val_Mean_Precision': 0.8512435581864228, 'CV_Val_Mean_Recall': 0.8834781687155575, 'CV_Val_Mean_ROC_AUC': 0.9234969400177662, 'Test_Accuracy': 0.8697225572979493, 'Test_F1': 0.8705035971223022, 'Test_Precision': 0.8789346246973365, 'Test_Recall': 0.8622327790973872, 'Test_ROC_AUC': 0.869841879744772}
# Training svm with select_percentile_50 and none on fp2...
# {'Fingerprint': 'fp2', 'Classifier': 'svm', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.8913207547169811, 0.8943396226415095, 0.8939622641509434, 0.8921161825726142, 0.8879668049792531], 'CV_Train_Mean_Accuracy': 0.8919411258122603, 'CV_Train_Mean_F1': 0.8959813401545731, 'CV_Train_Mean_Precision': 0.8762919223120761, 'CV_Train_Mean_Recall': 0.9166175975076918, 'CV_Train_Mean_ROC_AUC': 0.9642785593121115, 'CV_Val_Accuracy_Folds': [0.8657616892911011, 0.8702865761689291, 0.861236802413273, 0.8625377643504532, 0.8640483383685801], 'CV_Val_Mean_Accuracy': 0.8647742341184672, 'CV_Val_Mean_F1': 0.8699167842682831, 'CV_Val_Mean_Precision': 0.8503362755700261, 'CV_Val_Mean_Recall': 0.8906139607178183, 'CV_Val_Mean_ROC_AUC': 0.9267006012026254, 'Test_Accuracy': 0.8745476477683957, 'Test_F1': 0.8761904761904762, 'Test_Precision': 0.8782816229116945, 'Test_Recall': 0.8741092636579573, 'Test_ROC_AUC': 0.8745546318289786}
# Training lr with select_percentile_25 and pca on fp2...
# {'Fingerprint': 'fp2', 'Classifier': 'lr', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.8388679245283018, 0.8328301886792453, 0.829811320754717, 0.8276122218030931, 0.8340248962655602], 'CV_Train_Mean_Accuracy': 0.8326293104061835, 'CV_Train_Mean_F1': 0.8370988601001512, 'CV_Train_Mean_Precision': 0.8273816388110979, 'CV_Train_Mean_Recall': 0.8470586675651939, 'CV_Train_Mean_ROC_AUC': 0.9034840656973311, 'CV_Val_Accuracy_Folds': [0.8235294117647058, 0.8190045248868778, 0.8174962292609351, 0.824773413897281, 0.8308157099697885], 'CV_Val_Mean_Accuracy': 0.8231238579559177, 'CV_Val_Mean_F1': 0.8278452501250062, 'CV_Val_Mean_Precision': 0.8186171786693214, 'CV_Val_Mean_Recall': 0.8376995902218454, 'CV_Val_Mean_ROC_AUC': 0.889625578577103, 'Test_Accuracy': 0.8118214716525934, 'Test_F1': 0.8160377358490566, 'Test_Precision': 0.810304449648712, 'Test_Recall': 0.8218527315914489, 'Test_ROC_AUC': 0.8116616599133716}
# Training lr with select_percentile_25 and none on fp2...
# {'Fingerprint': 'fp2', 'Classifier': 'lr', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.8694339622641509, 0.8633962264150944, 0.8649056603773585, 0.8638249717087891, 0.8634477555639382], 'CV_Train_Mean_Accuracy': 0.8650017152658662, 'CV_Train_Mean_F1': 0.869009391186618, 'CV_Train_Mean_Precision': 0.8564580785573142, 'CV_Train_Mean_Recall': 0.8819857819119848, 'CV_Train_Mean_ROC_AUC': 0.941371652128075, 'CV_Val_Accuracy_Folds': [0.8190045248868778, 0.8159879336349924, 0.8159879336349924, 0.8323262839879154, 0.8368580060422961], 'CV_Val_Mean_Accuracy': 0.8240329364374149, 'CV_Val_Mean_F1': 0.8298331599642192, 'CV_Val_Mean_Precision': 0.8155109852093426, 'CV_Val_Mean_Recall': 0.8448353822241061, 'CV_Val_Mean_ROC_AUC': 0.9036056367389268, 'Test_Accuracy': 0.8576598311218335, 'Test_F1': 0.8601895734597157, 'Test_Precision': 0.8581560283687943, 'Test_Recall': 0.8622327790973872, 'Test_ROC_AUC': 0.8575869777839876}
# Training lr with select_percentile_50 and pca on fp2...
# {'Fingerprint': 'fp2', 'Classifier': 'lr', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.8550943396226415, 0.8566037735849057, 0.8566037735849057, 0.8551490003772162, 0.8525084873632591], 'CV_Train_Mean_Accuracy': 0.8551918749065857, 'CV_Train_Mean_F1': 0.8606902442393464, 'CV_Train_Mean_Precision': 0.8412346017527443, 'CV_Train_Mean_Recall': 0.881093699078089, 'CV_Train_Mean_ROC_AUC': 0.9262792102601803, 'CV_Val_Accuracy_Folds': [0.8446455505279035, 0.8355957767722474, 0.8386123680241327, 0.8413897280966768, 0.8655589123867069], 'CV_Val_Mean_Accuracy': 0.8451604671615334, 'CV_Val_Mean_F1': 0.8509276013823286, 'CV_Val_Mean_Precision': 0.8324004364529456, 'CV_Val_Mean_Recall': 0.8703917620460647, 'CV_Val_Mean_ROC_AUC': 0.9092886451141664, 'Test_Accuracy': 0.8624849215922799, 'Test_F1': 0.8683602771362586, 'Test_Precision': 0.8449438202247191, 'Test_Recall': 0.8931116389548693, 'Test_ROC_AUC': 0.8619969959480228}
# Training lr with select_percentile_50 and none on fp2...
# {'Fingerprint': 'fp2', 'Classifier': 'lr', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.9071698113207547, 0.9132075471698113, 0.9083018867924528, 0.9049415314975481, 0.9034326669181441], 'CV_Train_Mean_Accuracy': 0.9074106887397422, 'CV_Train_Mean_F1': 0.9102932936364017, 'CV_Train_Mean_Precision': 0.89585832865694, 'CV_Train_Mean_Recall': 0.9252388185840464, 'CV_Train_Mean_ROC_AUC': 0.9687544000189954, 'CV_Val_Accuracy_Folds': [0.8371040723981901, 0.8371040723981901, 0.8371040723981901, 0.8610271903323263, 0.8564954682779456], 'CV_Val_Mean_Accuracy': 0.8457669751609684, 'CV_Val_Mean_F1': 0.8506210853871478, 'CV_Val_Mean_Precision': 0.8370988503074915, 'CV_Val_Mean_Recall': 0.865064646036456, 'CV_Val_Mean_ROC_AUC': 0.9218243282926369, 'Test_Accuracy': 0.8468033775633294, 'Test_F1': 0.8511137162954279, 'Test_Precision': 0.8402777777777778, 'Test_Recall': 0.8622327790973872, 'Test_ROC_AUC': 0.8465575660192817}
# Training rf with select_percentile_25 and pca on fp2...
# {'Fingerprint': 'fp2', 'Classifier': 'rf', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.9441509433962264, 0.9467924528301886, 0.9384905660377358, 0.940022632968691, 0.938513768389287], 'CV_Train_Mean_Accuracy': 0.9415940727244259, 'CV_Train_Mean_F1': 0.9429019100745377, 'CV_Train_Mean_Precision': 0.9360057253460065, 'CV_Train_Mean_Recall': 0.9499120069378083, 'CV_Train_Mean_ROC_AUC': 0.9877787238588223, 'CV_Val_Accuracy_Folds': [0.8461538461538461, 0.8552036199095022, 0.8386123680241327, 0.8398791540785498, 0.8459214501510574], 'CV_Val_Mean_Accuracy': 0.8451540876634176, 'CV_Val_Mean_F1': 0.8492144825145347, 'CV_Val_Mean_Precision': 0.8401692015597767, 'CV_Val_Mean_Recall': 0.8590963685177335, 'CV_Val_Mean_ROC_AUC': 0.9152184140891059, 'Test_Accuracy': 0.8576598311218335, 'Test_F1': 0.8588516746411483, 'Test_Precision': 0.8650602409638555, 'Test_Recall': 0.8527315914489311, 'Test_ROC_AUC': 0.8577383447440734}
# Training rf with select_percentile_25 and none on fp2...
# {'Fingerprint': 'fp2', 'Classifier': 'rf', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.8860377358490567, 0.8837735849056604, 0.8811320754716981, 0.8864579403998492, 0.8872123726895511], 'CV_Train_Mean_Accuracy': 0.8849227418631631, 'CV_Train_Mean_F1': 0.8876513402873967, 'CV_Train_Mean_Precision': 0.8799552811665027, 'CV_Train_Mean_Recall': 0.8955115252683153, 'CV_Train_Mean_ROC_AUC': 0.9555476864895585, 'CV_Val_Accuracy_Folds': [0.8491704374057315, 0.8672699849170438, 0.8431372549019608, 0.851963746223565, 0.8489425981873112], 'CV_Val_Mean_Accuracy': 0.8520968043271224, 'CV_Val_Mean_F1': 0.8557149784449802, 'CV_Val_Mean_Precision': 0.8479930624236705, 'CV_Val_Mean_Recall': 0.863852974424191, 'CV_Val_Mean_ROC_AUC': 0.9216709500249645, 'Test_Accuracy': 0.8528347406513872, 'Test_F1': 0.8537170263788969, 'Test_Precision': 0.8619854721549637, 'Test_Recall': 0.8456057007125891, 'Test_ROC_AUC': 0.852949909179824}
# Training rf with select_percentile_50 and pca on fp2...
# {'Fingerprint': 'fp2', 'Classifier': 'rf', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.9592452830188679, 0.9581132075471698, 0.9528301886792453, 0.951716333459072, 0.955488494907582], 'CV_Train_Mean_Accuracy': 0.9554787015223875, 'CV_Train_Mean_F1': 0.9565251089647775, 'CV_Train_Mean_Precision': 0.9485622941597915, 'CV_Train_Mean_Recall': 0.9646260156763535, 'CV_Train_Mean_ROC_AUC': 0.9923850331677428, 'CV_Val_Accuracy_Folds': [0.861236802413273, 0.8702865761689291, 0.8536953242835595, 0.8444108761329305, 0.8625377643504532], 'CV_Val_Mean_Accuracy': 0.8584334686698292, 'CV_Val_Mean_F1': 0.8614520704134367, 'CV_Val_Mean_Precision': 0.8559256046198968, 'CV_Val_Mean_Recall': 0.8674155715698741, 'CV_Val_Mean_ROC_AUC': 0.9246782511000463, 'Test_Accuracy': 0.8636911942098915, 'Test_F1': 0.8640192539109507, 'Test_Precision': 0.875609756097561, 'Test_Recall': 0.8527315914489311, 'Test_ROC_AUC': 0.8638657957244655}
# Training rf with select_percentile_50 and none on fp2...
# {'Fingerprint': 'fp2', 'Classifier': 'rf', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.8943396226415095, 0.8939622641509434, 0.8913207547169811, 0.8913617502829121, 0.8928706148623161], 'CV_Train_Mean_Accuracy': 0.8927710013309325, 'CV_Train_Mean_F1': 0.8954859645354161, 'CV_Train_Mean_Precision': 0.8863193769238673, 'CV_Train_Mean_Recall': 0.9048766826670791, 'CV_Train_Mean_ROC_AUC': 0.9621287965329699, 'CV_Val_Accuracy_Folds': [0.8672699849170438, 0.8733031674208145, 0.8536953242835595, 0.8549848942598187, 0.8580060422960725], 'CV_Val_Mean_Accuracy': 0.8614518826354619, 'CV_Val_Mean_F1': 0.8643971680686381, 'CV_Val_Mean_Precision': 0.8592648696463577, 'CV_Val_Mean_Recall': 0.8697929913805285, 'CV_Val_Mean_ROC_AUC': 0.9288093698490144, 'Test_Accuracy': 0.8709288299155609, 'Test_F1': 0.8706166868198307, 'Test_Precision': 0.8866995073891626, 'Test_Recall': 0.8551068883610451, 'Test_ROC_AUC': 0.8711808951609146}
# Training xgb with select_percentile_25 and pca on fp2...
# {'Fingerprint': 'fp2', 'Classifier': 'xgb', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.9324528301886792, 0.9422641509433962, 0.9381132075471698, 0.936250471520181, 0.9321010939268201], 'CV_Train_Mean_Accuracy': 0.9362363508252493, 'CV_Train_Mean_F1': 0.9374967765303115, 'CV_Train_Mean_Precision': 0.9331537316371566, 'CV_Train_Mean_Recall': 0.9418852499765242, 'CV_Train_Mean_ROC_AUC': 0.9856532120560739, 'CV_Val_Accuracy_Folds': [0.8416289592760181, 0.8506787330316742, 0.8310708898944194, 0.8444108761329305, 0.8338368580060423], 'CV_Val_Mean_Accuracy': 0.8403252632682168, 'CV_Val_Mean_F1': 0.8439711505099632, 'CV_Val_Mean_Precision': 0.8377580660733489, 'CV_Val_Mean_Recall': 0.8507718666101456, 'CV_Val_Mean_ROC_AUC': 0.9177220314129902, 'Test_Accuracy': 0.8600723763570567, 'Test_F1': 0.8628841607565012, 'Test_Precision': 0.8588235294117647, 'Test_Recall': 0.8669833729216152, 'Test_ROC_AUC': 0.8599622746961018}
# Training xgb with select_percentile_25 and none on fp2...
# {'Fingerprint': 'fp2', 'Classifier': 'xgb', 'Feature_Selection_Method': 'select_percentile_25', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.8883018867924528, 0.8807547169811321, 0.8852830188679245, 0.8841946435307431, 0.8834402112410411], 'CV_Train_Mean_Accuracy': 0.8843948954826587, 'CV_Train_Mean_F1': 0.8875664713190966, 'CV_Train_Mean_Precision': 0.8766328397924502, 'CV_Train_Mean_Recall': 0.8987815750371471, 'CV_Train_Mean_ROC_AUC': 0.9547833738602538, 'CV_Val_Accuracy_Folds': [0.8521870286576169, 0.8687782805429864, 0.8371040723981901, 0.8429003021148036, 0.8398791540785498], 'CV_Val_Mean_Accuracy': 0.8481697675584294, 'CV_Val_Mean_F1': 0.8524749527693263, 'CV_Val_Mean_Precision': 0.8416862934974105, 'CV_Val_Mean_Recall': 0.8638441429984457, 'CV_Val_Mean_ROC_AUC': 0.9207605491035066, 'Test_Accuracy': 0.8516284680337757, 'Test_F1': 0.8530465949820788, 'Test_Precision': 0.8581730769230769, 'Test_Recall': 0.8479809976247031, 'Test_ROC_AUC': 0.851686577243724}
# Training xgb with select_percentile_50 and pca on fp2...
# {'Fingerprint': 'fp2', 'Classifier': 'xgb', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'pca', 'CV_Train_Accuracy_Folds': [0.9528301886792453, 0.9550943396226416, 0.9516981132075472, 0.9471897397208601, 0.949830252734817], 'CV_Train_Mean_Accuracy': 0.9513285267930222, 'CV_Train_Mean_F1': 0.9523748099268655, 'CV_Train_Mean_Precision': 0.9461794388512461, 'CV_Train_Mean_Recall': 0.9586817059496126, 'CV_Train_Mean_ROC_AUC': 0.991326911607227, 'CV_Val_Accuracy_Folds': [0.8521870286576169, 0.8536953242835595, 0.8491704374057315, 0.8398791540785498, 0.8625377643504532], 'CV_Val_Mean_Accuracy': 0.8514939417551821, 'CV_Val_Mean_F1': 0.8561058747167622, 'CV_Val_Mean_Precision': 0.8424408116660042, 'CV_Val_Mean_Recall': 0.870398827186661, 'CV_Val_Mean_ROC_AUC': 0.9280161289467836, 'Test_Accuracy': 0.8624849215922799, 'Test_F1': 0.8652482269503546, 'Test_Precision': 0.8611764705882353, 'Test_Recall': 0.8693586698337292, 'Test_ROC_AUC': 0.8623754133482371}
# Training xgb with select_percentile_50 and none on fp2...
# {'Fingerprint': 'fp2', 'Classifier': 'xgb', 'Feature_Selection_Method': 'select_percentile_50', 'Dimensionality_Reduction_Method': 'none', 'CV_Train_Accuracy_Folds': [0.8958490566037736, 0.8939622641509434, 0.889811320754717, 0.8928706148623161, 0.8928706148623161], 'CV_Train_Mean_Accuracy': 0.8930727742468132, 'CV_Train_Mean_F1': 0.8961812350093081, 'CV_Train_Mean_Precision': 0.8836926688640272, 'CV_Train_Mean_Recall': 0.9090373790993, 'CV_Train_Mean_ROC_AUC': 0.9603995585966658, 'CV_Val_Accuracy_Folds': [0.8536953242835595, 0.8687782805429864, 0.8431372549019608, 0.8564954682779456, 0.850453172205438], 'CV_Val_Mean_Accuracy': 0.8545119000423782, 'CV_Val_Mean_F1': 0.858929199324064, 'CV_Val_Mean_Precision': 0.8464983557106578, 'CV_Val_Mean_Recall': 0.8721810089020771, 'CV_Val_Mean_ROC_AUC': 0.9264094551123945, 'Test_Accuracy': 0.8588661037394452, 'Test_F1': 0.8608799048751486, 'Test_Precision': 0.861904761904762, 'Test_Recall': 0.8598574821852731, 'Test_ROC_AUC': 0.8588503097200876}

# %%
results_df.to_csv(f'{kon.path_files}/rezultati_modelov/results_df_new12.csv', index=False)
