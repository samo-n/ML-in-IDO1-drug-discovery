# %% [markdown]
# # Optimizacija hiperparametrov RF

# %%
# %run __A_knjiznice.py

# Import specific elements from the script
from __A_knjiznice import *
from __B_funkcije import *
import __C_konstante as kon
# %matplotlib inline

# %%
import optuna
from sklearn.model_selection import StratifiedKFold, cross_val_score, train_test_split
from sklearn.ensemble import RandomForestClassifier  # Import Random Forest Classifier
from sklearn.feature_selection import SelectPercentile, chi2, VarianceThreshold
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay
import pandas as pd
import numpy as np
from optuna.pruners import MedianPruner

# Load your dataset
df = pd.read_csv(f'{kon.path_files}/molekulski_prstni_odtisi/df_rdkit.csv')
y = df[['Activity']].values.ravel()  # Assuming 'Activity' is the target
X = df.iloc[:, 3:]

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=kon.random_seed, stratify=y)

# Define cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=kon.random_seed)

# Define the Optuna optimization function
def objective(trial):
    # Random Forest hyperparameters
    n_estimators = trial.suggest_int('n_estimators', 10, 200)  # Number of trees in the forest
    max_depth = trial.suggest_int('max_depth', 1, 20)  # Maximum depth of the trees
    min_samples_split = trial.suggest_int('min_samples_split', 5, 10)  # Min samples required to split an internal node
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 5, 10)  # Min samples required at a leaf node
    
    # Feature selection with SelectPercentile
    percentile = trial.suggest_int('percentile', 5, 50)  # Percentile between 5 and 60
    
    # Build the pipeline
    model = Pipeline([
        ('variance_threshold', VarianceThreshold()),  # Remove low-variance features
        ('select_percentile', SelectPercentile(score_func=chi2, percentile=percentile)),  # Feature selection
        ('random_forest', RandomForestClassifier(
            n_estimators=n_estimators, 
            max_depth=max_depth,
            min_samples_split=min_samples_split,
            min_samples_leaf=min_samples_leaf,
            random_state=kon.random_seed
        ))  # Random Forest Classifier
    ])
    
    # Cross-validation: Optimize based on mean accuracy
    cv_scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy')
    return np.mean(cv_scores)  # Return the mean of the cross-validation scores

# Create the Optuna study and optimize it
study = optuna.create_study(direction='maximize', pruner=MedianPruner())  # Maximize accuracy
study.optimize(objective, n_trials=100)  # Adjust n_trials as needed

# Output the best trial results
print('Best trial:')
best_trial = study.best_trial
print(f"  Value: {best_trial.value}")
print(f"  Params: {best_trial.params}")
# Out:
# [I 2025-01-26 19:44:49,493] A new study created in memory with name: no-name-26ac3469-2296-48dd-b2be-874d7fc39649
# [I 2025-01-26 19:44:50,935] Trial 0 finished with value: 0.8644702966010944 and parameters: {'n_estimators': 84, 'max_depth': 9, 'min_samples_split': 7, 'min_samples_leaf': 9, 'percentile': 24}. Best is trial 0 with value: 0.8644702966010944.
# [I 2025-01-26 19:44:51,583] Trial 1 finished with value: 0.8539131385763694 and parameters: {'n_estimators': 36, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 9, 'percentile': 11}. Best is trial 0 with value: 0.8644702966010944.
# [I 2025-01-26 19:44:52,725] Trial 2 finished with value: 0.8551161296496288 and parameters: {'n_estimators': 97, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 10, 'percentile': 12}. Best is trial 0 with value: 0.8644702966010944.
# [I 2025-01-26 19:44:53,768] Trial 3 finished with value: 0.8702045540502977 and parameters: {'n_estimators': 48, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 5, 'percentile': 36}. Best is trial 3 with value: 0.8702045540502977.
# [I 2025-01-26 19:44:54,700] Trial 4 finished with value: 0.8617535417606504 and parameters: {'n_estimators': 36, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 8, 'percentile': 44}. Best is trial 3 with value: 0.8702045540502977.
# [I 2025-01-26 19:44:57,049] Trial 5 finished with value: 0.8680897504249202 and parameters: {'n_estimators': 163, 'max_depth': 14, 'min_samples_split': 10, 'min_samples_leaf': 7, 'percentile': 43}. Best is trial 3 with value: 0.8702045540502977.
# [I 2025-01-26 19:44:57,819] Trial 6 finished with value: 0.8602425120640866 and parameters: {'n_estimators': 31, 'max_depth': 7, 'min_samples_split': 7, 'min_samples_leaf': 7, 'percentile': 42}. Best is trial 3 with value: 0.8702045540502977.
# [I 2025-01-26 19:44:59,543] Trial 7 finished with value: 0.8517960565588076 and parameters: {'n_estimators': 194, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 6, 'percentile': 5}. Best is trial 3 with value: 0.8702045540502977.
# [I 2025-01-26 19:45:02,254] Trial 8 finished with value: 0.8699033506035461 and parameters: {'n_estimators': 188, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 7, 'percentile': 37}. Best is trial 3 with value: 0.8702045540502977.
# [I 2025-01-26 19:45:03,792] Trial 9 finished with value: 0.8533066305769343 and parameters: {'n_estimators': 162, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 10, 'percentile': 7}. Best is trial 3 with value: 0.8702045540502977.
# [I 2025-01-26 19:45:04,481] Trial 10 finished with value: 0.7914295999599003 and parameters: {'n_estimators': 72, 'max_depth': 2, 'min_samples_split': 9, 'min_samples_leaf': 5, 'percentile': 30}. Best is trial 3 with value: 0.8702045540502977.
# [I 2025-01-26 19:45:06,551] Trial 11 finished with value: 0.8702063767640451 and parameters: {'n_estimators': 127, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 34}. Best is trial 11 with value: 0.8702063767640451.
# [I 2025-01-26 19:45:08,376] Trial 12 finished with value: 0.8744309715519952 and parameters: {'n_estimators': 122, 'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 30}. Best is trial 12 with value: 0.8744309715519952.
# [I 2025-01-26 19:45:10,149] Trial 13 finished with value: 0.867489166245164 and parameters: {'n_estimators': 129, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 21}. Best is trial 12 with value: 0.8744309715519952.
# [I 2025-01-26 19:45:12,400] Trial 14 finished with value: 0.8726187384086798 and parameters: {'n_estimators': 124, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 6, 'percentile': 50}. Best is trial 12 with value: 0.8744309715519952.
# [I 2025-01-26 19:45:13,943] Trial 15 finished with value: 0.8680924844955411 and parameters: {'n_estimators': 120, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 6, 'percentile': 18}. Best is trial 12 with value: 0.8744309715519952.
# [I 2025-01-26 19:45:16,442] Trial 16 finished with value: 0.8723179906403649 and parameters: {'n_estimators': 156, 'max_depth': 17, 'min_samples_split': 6, 'min_samples_leaf': 6, 'percentile': 48}. Best is trial 12 with value: 0.8744309715519952.
# [I 2025-01-26 19:45:18,791] Trial 17 finished with value: 0.8723170792834912 and parameters: {'n_estimators': 141, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 6, 'percentile': 50}. Best is trial 12 with value: 0.8744309715519952.
# [I 2025-01-26 19:45:20,436] Trial 18 finished with value: 0.8708069609438012 and parameters: {'n_estimators': 104, 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 6, 'percentile': 28}. Best is trial 12 with value: 0.8744309715519952.
# [I 2025-01-26 19:45:21,668] Trial 19 finished with value: 0.8662784286384785 and parameters: {'n_estimators': 65, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 8, 'percentile': 31}. Best is trial 12 with value: 0.8744309715519952.
# [I 2025-01-26 19:45:23,348] Trial 20 finished with value: 0.8671852287277915 and parameters: {'n_estimators': 115, 'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 5, 'percentile': 17}. Best is trial 12 with value: 0.8744309715519952.
# [I 2025-01-26 19:45:25,905] Trial 21 finished with value: 0.8735255384979927 and parameters: {'n_estimators': 158, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 6, 'percentile': 50}. Best is trial 12 with value: 0.8744309715519952.
# [I 2025-01-26 19:45:28,174] Trial 22 finished with value: 0.8732225123374937 and parameters: {'n_estimators': 143, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 6, 'percentile': 46}. Best is trial 12 with value: 0.8744309715519952.
# [I 2025-01-26 19:45:30,782] Trial 23 finished with value: 0.8683936879422929 and parameters: {'n_estimators': 179, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 7, 'percentile': 40}. Best is trial 12 with value: 0.8744309715519952.
# [I 2025-01-26 19:45:33,149] Trial 24 finished with value: 0.8744318829088689 and parameters: {'n_estimators': 144, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 47}. Best is trial 24 with value: 0.8744318829088689.
# [I 2025-01-26 19:45:34,315] Trial 25 finished with value: 0.7947565082272743 and parameters: {'n_estimators': 150, 'max_depth': 2, 'min_samples_split': 6, 'min_samples_leaf': 5, 'percentile': 40}. Best is trial 24 with value: 0.8744318829088689.
# [I 2025-01-26 19:45:37,108] Trial 26 finished with value: 0.8747326306771838 and parameters: {'n_estimators': 174, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 45}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:45:39,356] Trial 27 finished with value: 0.8726201054439903 and parameters: {'n_estimators': 173, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 24}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:45:41,410] Trial 28 finished with value: 0.8566239695971347 and parameters: {'n_estimators': 200, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 33}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:45:42,700] Trial 29 finished with value: 0.8635653192255288 and parameters: {'n_estimators': 85, 'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 9, 'percentile': 25}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:45:44,750] Trial 30 finished with value: 0.8720167871936132 and parameters: {'n_estimators': 137, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 5, 'percentile': 38}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:45:47,412] Trial 31 finished with value: 0.8714130132647993 and parameters: {'n_estimators': 174, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 6, 'percentile': 46}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:45:49,613] Trial 32 finished with value: 0.8683945992991665 and parameters: {'n_estimators': 153, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 5, 'percentile': 47}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:45:52,291] Trial 33 finished with value: 0.8741302237836803 and parameters: {'n_estimators': 169, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 44}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:45:54,194] Trial 34 finished with value: 0.8665814547989774 and parameters: {'n_estimators': 110, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 41}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:45:56,972] Trial 35 finished with value: 0.8744314272304321 and parameters: {'n_estimators': 178, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 45}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:45:59,563] Trial 36 finished with value: 0.8711113541396107 and parameters: {'n_estimators': 183, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 5, 'percentile': 38}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:46:00,154] Trial 37 finished with value: 0.862661253206837 and parameters: {'n_estimators': 18, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 7, 'percentile': 45}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:46:01,383] Trial 38 finished with value: 0.8548131034891299 and parameters: {'n_estimators': 93, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 8, 'percentile': 35}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:46:04,182] Trial 39 finished with value: 0.8708096950144222 and parameters: {'n_estimators': 190, 'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 6, 'percentile': 43}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:46:06,424] Trial 40 finished with value: 0.8708083279791117 and parameters: {'n_estimators': 133, 'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 5, 'percentile': 41}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:46:09,196] Trial 41 finished with value: 0.8741288567483698 and parameters: {'n_estimators': 168, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 44}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:46:11,723] Trial 42 finished with value: 0.8623582270463379 and parameters: {'n_estimators': 167, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 10, 'percentile': 48}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:46:13,416] Trial 43 finished with value: 0.8650758932436557 and parameters: {'n_estimators': 145, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 13}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:46:16,231] Trial 44 finished with value: 0.8732229680159305 and parameters: {'n_estimators': 183, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 43}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:46:19,193] Trial 45 finished with value: 0.8720158758367396 and parameters: {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 5, 'percentile': 39}. Best is trial 26 with value: 0.8747326306771838.
# [I 2025-01-26 19:46:21,689] Trial 46 finished with value: 0.8747335420340574 and parameters: {'n_estimators': 164, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 6, 'percentile': 47}. Best is trial 46 with value: 0.8747335420340574.
# [I 2025-01-26 19:46:24,131] Trial 47 finished with value: 0.8702040983718609 and parameters: {'n_estimators': 162, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 6, 'percentile': 48}. Best is trial 46 with value: 0.8747335420340574.
# [I 2025-01-26 19:46:26,284] Trial 48 finished with value: 0.8677894583350421 and parameters: {'n_estimators': 152, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 7, 'percentile': 36}. Best is trial 46 with value: 0.8747335420340574.
# [I 2025-01-26 19:46:28,401] Trial 49 finished with value: 0.8677885469781683 and parameters: {'n_estimators': 178, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 6, 'percentile': 21}. Best is trial 46 with value: 0.8747335420340574.
# [I 2025-01-26 19:46:30,649] Trial 50 finished with value: 0.860244334777834 and parameters: {'n_estimators': 191, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 6, 'percentile': 32}. Best is trial 46 with value: 0.8747335420340574.
# [I 2025-01-26 19:46:33,468] Trial 51 finished with value: 0.8753377716413082 and parameters: {'n_estimators': 170, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 45}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:46:36,182] Trial 52 finished with value: 0.87473171932031 and parameters: {'n_estimators': 162, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 49}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:46:39,008] Trial 53 finished with value: 0.8738285646584918 and parameters: {'n_estimators': 163, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 50}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:46:41,957] Trial 54 finished with value: 0.8714130132647993 and parameters: {'n_estimators': 185, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 46}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:46:44,588] Trial 55 finished with value: 0.8668844809594765 and parameters: {'n_estimators': 174, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 9, 'percentile': 48}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:46:46,997] Trial 56 finished with value: 0.87050712453236 and parameters: {'n_estimators': 147, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 6, 'percentile': 42}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:46:49,535] Trial 57 finished with value: 0.875032011410188 and parameters: {'n_estimators': 162, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 45}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:46:52,163] Trial 58 finished with value: 0.869600324443047 and parameters: {'n_estimators': 159, 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 6, 'percentile': 49}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:46:54,573] Trial 59 finished with value: 0.8726196497655534 and parameters: {'n_estimators': 137, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 5, 'percentile': 47}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:46:56,920] Trial 60 finished with value: 0.8708119734066064 and parameters: {'n_estimators': 155, 'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 6, 'percentile': 42}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:46:59,673] Trial 61 finished with value: 0.8726205611224271 and parameters: {'n_estimators': 179, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 44}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:47:02,147] Trial 62 finished with value: 0.8732261577649885 and parameters: {'n_estimators': 165, 'max_depth': 8, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 45}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:47:04,959] Trial 63 finished with value: 0.874128401069933 and parameters: {'n_estimators': 174, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 46}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:47:07,974] Trial 64 finished with value: 0.8741288567483698 and parameters: {'n_estimators': 193, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 49}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:47:10,505] Trial 65 finished with value: 0.8747330863556206 and parameters: {'n_estimators': 158, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 45}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:47:13,161] Trial 66 finished with value: 0.8726214724793009 and parameters: {'n_estimators': 158, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 5, 'percentile': 50}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:47:15,660] Trial 67 finished with value: 0.8723179906403649 and parameters: {'n_estimators': 150, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 47}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:47:17,842] Trial 68 finished with value: 0.8735241714626822 and parameters: {'n_estimators': 140, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 5, 'percentile': 40}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:47:18,917] Trial 69 finished with value: 0.8668826582457292 and parameters: {'n_estimators': 49, 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 6, 'percentile': 43}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:47:21,639] Trial 70 finished with value: 0.8723202690325491 and parameters: {'n_estimators': 169, 'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 6, 'percentile': 47}. Best is trial 51 with value: 0.8753377716413082.
# [I 2025-01-26 19:47:24,429] Trial 71 finished with value: 0.8765444081420621 and parameters: {'n_estimators': 179, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 45}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:47:27,062] Trial 72 finished with value: 0.8753368602844345 and parameters: {'n_estimators': 162, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 45}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:47:29,979] Trial 73 finished with value: 0.8753373159628713 and parameters: {'n_estimators': 186, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 45}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:47:32,896] Trial 74 finished with value: 0.8762427490168736 and parameters: {'n_estimators': 188, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 45}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:47:35,667] Trial 75 finished with value: 0.8702054654071715 and parameters: {'n_estimators': 186, 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 41}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:47:38,687] Trial 76 finished with value: 0.8720186099073606 and parameters: {'n_estimators': 196, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 42}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:47:41,432] Trial 77 finished with value: 0.8735241714626822 and parameters: {'n_estimators': 188, 'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 38}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:47:44,295] Trial 78 finished with value: 0.8738276533016182 and parameters: {'n_estimators': 182, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 44}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:47:47,264] Trial 79 finished with value: 0.8744332499441793 and parameters: {'n_estimators': 195, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 7, 'percentile': 45}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:47:49,902] Trial 80 finished with value: 0.8714130132647993 and parameters: {'n_estimators': 174, 'max_depth': 19, 'min_samples_split': 6, 'min_samples_leaf': 6, 'percentile': 43}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:47:52,673] Trial 81 finished with value: 0.8762427490168736 and parameters: {'n_estimators': 170, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 45}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:47:55,489] Trial 82 finished with value: 0.8738285646584918 and parameters: {'n_estimators': 170, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 46}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:47:58,247] Trial 83 finished with value: 0.8705048461401758 and parameters: {'n_estimators': 179, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 40}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:48:00,836] Trial 84 finished with value: 0.8738285646584918 and parameters: {'n_estimators': 159, 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 44}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:48:03,826] Trial 85 finished with value: 0.8726205611224271 and parameters: {'n_estimators': 188, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 46}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:48:06,548] Trial 86 finished with value: 0.8747321749987469 and parameters: {'n_estimators': 166, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 48}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:48:09,143] Trial 87 finished with value: 0.8686958027459182 and parameters: {'n_estimators': 171, 'max_depth': 17, 'min_samples_split': 6, 'min_samples_leaf': 8, 'percentile': 41}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:48:11,671] Trial 88 finished with value: 0.8729222202476157 and parameters: {'n_estimators': 179, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 28}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:48:13,249] Trial 89 finished with value: 0.8566216912049505 and parameters: {'n_estimators': 153, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 8}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:48:16,296] Trial 90 finished with value: 0.8756389750880599 and parameters: {'n_estimators': 197, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 45}. Best is trial 71 with value: 0.8765444081420621.
# [I 2025-01-26 19:48:19,165] Trial 91 finished with value: 0.876544863820499 and parameters: {'n_estimators': 183, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 45}. Best is trial 91 with value: 0.876544863820499.
# [I 2025-01-26 19:48:22,281] Trial 92 finished with value: 0.8720154201583027 and parameters: {'n_estimators': 198, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 43}. Best is trial 91 with value: 0.876544863820499.
# [I 2025-01-26 19:48:25,385] Trial 93 finished with value: 0.8753350375706871 and parameters: {'n_estimators': 192, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 48}. Best is trial 91 with value: 0.876544863820499.
# [I 2025-01-26 19:48:28,414] Trial 94 finished with value: 0.8729213088907419 and parameters: {'n_estimators': 192, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 49}. Best is trial 91 with value: 0.876544863820499.
# [I 2025-01-26 19:48:31,283] Trial 95 finished with value: 0.8744327942657426 and parameters: {'n_estimators': 183, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 44}. Best is trial 91 with value: 0.876544863820499.
# [I 2025-01-26 19:48:34,023] Trial 96 finished with value: 0.8644702966010944 and parameters: {'n_estimators': 200, 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 10, 'percentile': 39}. Best is trial 91 with value: 0.876544863820499.
# [I 2025-01-26 19:48:36,972] Trial 97 finished with value: 0.8726219281577376 and parameters: {'n_estimators': 189, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 42}. Best is trial 91 with value: 0.876544863820499.
# [I 2025-01-26 19:48:40,104] Trial 98 finished with value: 0.8747321749987469 and parameters: {'n_estimators': 195, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 48}. Best is trial 91 with value: 0.876544863820499.
# [I 2025-01-26 19:48:43,031] Trial 99 finished with value: 0.8762427490168736 and parameters: {'n_estimators': 182, 'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 5, 'percentile': 45}. Best is trial 91 with value: 0.876544863820499.
# Best trial:
#   Value: 0.876544863820499
#   Params: {'n_estimators': 183, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 5, 'percentile': 45}

# %%
# Extract the best hyperparameters from Optuna
best_params = best_trial.params
n_estimators = best_params['n_estimators']
max_depth = best_params['max_depth']
min_samples_split = best_params['min_samples_split']
min_samples_leaf = best_params['min_samples_leaf']
percentile = best_params['percentile']

# Create the final pipeline with the best parameters
final_model = Pipeline([
    ('variance_threshold', VarianceThreshold()),  # Remove low variance features
    ('select_percentile', SelectPercentile(score_func=chi2, percentile=percentile)),  # Feature selection
    ('random_forest', RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        random_state=kon.random_seed
    ))  # Random Forest Classifier with best parameters
])

# Fit the model on the full training data
final_model.fit(X_train, y_train)

# Predictions for train data
y_train_pred = final_model.predict(X_train)
y_train_prob = final_model.predict_proba(X_train)[:, 1]  # Probabilities for ROC AUC

# Predictions for test data
y_test_pred = final_model.predict(X_test)
y_test_prob = final_model.predict_proba(X_test)[:, 1]  # Probabilities for ROC AUC

# Calculate accuracy and AUC for train and test sets
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

train_auc = roc_auc_score(y_train, y_train_prob)
test_auc = roc_auc_score(y_test, y_test_prob)

# Print performance metrics
print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Train AUC: {train_auc:.4f}")
print(f"Test AUC: {test_auc:.4f}")

# Plot ROC Curve
fpr_train, tpr_train, _ = roc_curve(y_train, y_train_prob)
fpr_test, tpr_test, _ = roc_curve(y_test, y_test_prob)

plt.figure(figsize=(10, 6))
plt.plot(fpr_train, tpr_train, color='blue', label=f'Train ROC Curve (AUC = {train_auc:.2f})')
plt.plot(fpr_test, tpr_test, color='red', label=f'Test ROC Curve (AUC = {test_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Random classifier line
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()
# Out:
# Train Accuracy: 0.9191
# Test Accuracy: 0.8758
# Train AUC: 0.9791
# Test AUC: 0.9365

# %%
# plot TEST only
plt.figure(figsize=(10, 6))
plt.plot(fpr_test, tpr_test, color='blue', label=f'ROC krivulja (AUC = {test_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Random classifier line
plt.title('ROC graf: RF')
plt.xlabel('Delež lažno pozitivnih')
plt.ylabel('Delež resnično pozitivnih')
plt.legend(loc='lower right')
plt.show()

# %%
# Confusion Matrix for Train and Test
train_cm = confusion_matrix(y_train, y_train_pred)
test_cm = confusion_matrix(y_test, y_test_pred)

# Print accuracy and AUC scores
print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Train AUC: {train_auc:.4f}")
print(f"Test AUC: {test_auc:.4f}")


# Display Confusion Matrix for Train data
fig, ax = plt.subplots(figsize=(6, 6))
ConfusionMatrixDisplay(confusion_matrix=train_cm).plot(cmap='Blues', ax=ax)
ax.set_title('Train Data Confusion Matrix')
plt.show()

# Display Confusion Matrix for Test data
fig, ax = plt.subplots(figsize=(6, 6))
ConfusionMatrixDisplay(confusion_matrix=test_cm).plot(cmap='Reds', ax=ax)
ax.set_title('Test Data Confusion Matrix')
plt.show()
# Out:
# Train Accuracy: 0.9191
# Test Accuracy: 0.8758
# Train AUC: 0.9791
# Test AUC: 0.9365
